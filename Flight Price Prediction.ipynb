# %% [markdown]
# # Training Dataset

# %% [markdown]
# # Data Description

# %% [markdown]
# The task is to build a machine learning model and predict the price of the flight ticket. The dataset consists of prices of flight tickets for various airlines between the months of March and June of 2019 and between various cities.

# %% [markdown]
# Size of Dataset-
#
#      Size of training set: 10683 records
#      Size of test set: 2671 records

# %% [markdown]
# Features-
#
#         Airline: The name of the airline.
#         Date_of_Journey: The date of the journey
#         Source: The source from which the service begins.
#         Destination: The destination where the service ends.
#         Route: The route taken by the flight to reach the destination.
#         Dep_Time: The time when the journey starts from the source.
#         Arrival_Time: Time of arrival at the destination.
#         Duration: Total duration of the flight.
#         Total_Stops: Total stops between the source and destination.
#         Additional_Info: Additional information about the flight
#         Price: The price of the ticket

# %% [markdown]
# # Importing Dataset

# %%
#Importing Libraries
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
# Importing Training Dataset
df=pd.read_excel('Data_Train.xlsx')
#Visualizing dataset
df
# Out:
#                  Airline Date_of_Journey    Source Destination  \
# 0                 IndiGo      24/03/2019  Banglore   New Delhi
# 1              Air India       1/05/2019   Kolkata    Banglore
# 2            Jet Airways       9/06/2019     Delhi      Cochin
# 3                 IndiGo      12/05/2019   Kolkata    Banglore
# 4                 IndiGo      01/03/2019  Banglore   New Delhi
# 5               SpiceJet      24/06/2019   Kolkata    Banglore
# 6            Jet Airways      12/03/2019  Banglore   New Delhi
# 7            Jet Airways      01/03/2019  Banglore   New Delhi
# 8            Jet Airways      12/03/2019  Banglore   New Delhi
# 9      Multiple carriers      27/05/2019     Delhi      Cochin
# 10             Air India       1/06/2019     Delhi      Cochin
# 11                IndiGo      18/04/2019   Kolkata    Banglore
# 12             Air India      24/06/2019   Chennai     Kolkata
# 13           Jet Airways       9/05/2019   Kolkata    Banglore
# 14                IndiGo      24/04/2019   Kolkata    Banglore
# 15             Air India       3/03/2019     Delhi      Cochin
# 16              SpiceJet      15/04/2019     Delhi      Cochin
# 17           Jet Airways      12/06/2019     Delhi      Cochin
# 18             Air India      12/06/2019     Delhi      Cochin
# 19           Jet Airways      27/05/2019     Delhi      Cochin
# 20                 GoAir       6/03/2019     Delhi      Cochin
# 21             Air India      21/03/2019  Banglore   New Delhi
# 22                IndiGo       3/04/2019  Banglore       Delhi
# 23                IndiGo       1/05/2019  Banglore       Delhi
# 24           Jet Airways       6/05/2019   Kolkata    Banglore
# 25           Jet Airways       9/06/2019     Delhi      Cochin
# 26                IndiGo       1/06/2019     Delhi      Cochin
# 27                 GoAir      15/05/2019     Delhi      Cochin
# 28               Vistara      18/06/2019  Banglore       Delhi
# 29               Vistara      15/06/2019   Chennai     Kolkata
# ...                  ...             ...       ...         ...
# 10653        Jet Airways       1/05/2019   Kolkata    Banglore
# 10654           SpiceJet      12/06/2019  Banglore       Delhi
# 10655        Jet Airways       3/05/2019    Mumbai   Hyderabad
# 10656            Vistara       6/04/2019  Banglore       Delhi
# 10657        Jet Airways       6/05/2019   Kolkata    Banglore
# 10658        Jet Airways      18/06/2019  Banglore       Delhi
# 10659            Vistara       1/05/2019  Banglore       Delhi
# 10660            Vistara      21/03/2019  Banglore   New Delhi
# 10661          Air India       9/05/2019     Delhi      Cochin
# 10662          Air India      24/03/2019   Kolkata    Banglore
# 10663        Jet Airways       6/06/2019     Delhi      Cochin
# 10664             IndiGo       9/04/2019  Banglore       Delhi
# 10665             IndiGo      27/04/2019   Kolkata    Banglore
# 10666        Jet Airways      12/06/2019     Delhi      Cochin
# 10667        Jet Airways      12/03/2019  Banglore   New Delhi
# 10668        Jet Airways       9/05/2019     Delhi      Cochin
# 10669          Air India      15/06/2019     Delhi      Cochin
# 10670          Air India      12/05/2019   Kolkata    Banglore
# 10671          Air India       6/06/2019    Mumbai   Hyderabad
# 10672        Jet Airways      27/06/2019     Delhi      Cochin
# 10673        Jet Airways      27/05/2019     Delhi      Cochin
# 10674        Jet Airways      12/03/2019  Banglore   New Delhi
# 10675          Air India       9/06/2019    Mumbai   Hyderabad
# 10676  Multiple carriers       1/05/2019     Delhi      Cochin
# 10677           SpiceJet      21/05/2019  Banglore       Delhi
# 10678           Air Asia       9/04/2019   Kolkata    Banglore
# 10679          Air India      27/04/2019   Kolkata    Banglore
# 10680        Jet Airways      27/04/2019  Banglore       Delhi
# 10681            Vistara      01/03/2019  Banglore   New Delhi
# 10682          Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# 2      DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# 3            CCU → NAG → BLR    18:05         23:30   5h 25m      1 stop
# 4            BLR → NAG → DEL    16:50         21:35   4h 45m      1 stop
# 5                  CCU → BLR    09:00         11:25   2h 25m    non-stop
# 6            BLR → BOM → DEL    18:55  10:25 13 Mar  15h 30m      1 stop
# 7            BLR → BOM → DEL    08:00  05:05 02 Mar   21h 5m      1 stop
# 8            BLR → BOM → DEL    08:55  10:25 13 Mar  25h 30m      1 stop
# 9            DEL → BOM → COK    11:25         19:15   7h 50m      1 stop
# 10           DEL → BLR → COK    09:45         23:00  13h 15m      1 stop
# 11                 CCU → BLR    20:20         22:55   2h 35m    non-stop
# 12                 MAA → CCU    11:40         13:55   2h 15m    non-stop
# 13           CCU → BOM → BLR    21:10  09:20 10 May  12h 10m      1 stop
# 14                 CCU → BLR    17:15         19:50   2h 35m    non-stop
# 15     DEL → AMD → BOM → COK    16:40  19:15 04 Mar  26h 35m     2 stops
# 16           DEL → PNQ → COK    08:45         13:15   4h 30m      1 stop
# 17           DEL → BOM → COK    14:00  12:35 13 Jun  22h 35m      1 stop
# 18     DEL → CCU → BOM → COK    20:15  19:15 13 Jun      23h     2 stops
# 19           DEL → BOM → COK    16:00  12:35 28 May  20h 35m      1 stop
# 20           DEL → BOM → COK    14:10         19:20   5h 10m      1 stop
# 21           BLR → COK → DEL    22:00  13:20 19 Mar  15h 20m      1 stop
# 22                 BLR → DEL    04:00         06:50   2h 50m    non-stop
# 23                 BLR → DEL    18:55         21:50   2h 55m    non-stop
# 24           CCU → BOM → BLR    18:55  08:15 07 May  13h 20m      1 stop
# 25     DEL → IDR → BOM → COK    21:25  12:35 10 Jun  15h 10m     2 stops
# 26           DEL → LKO → COK    21:50  03:35 02 Jun   5h 45m      1 stop
# 27           DEL → BOM → COK    07:00         12:55   5h 55m      1 stop
# 28                 BLR → DEL    09:45         12:35   2h 50m    non-stop
# 29                 MAA → CCU    07:05         09:20   2h 15m    non-stop
# ...                      ...      ...           ...      ...         ...
# 10653        CCU → BOM → BLR    14:05  12:00 02 May  21h 55m      1 stop
# 10654              BLR → DEL    05:55         08:35   2h 40m    non-stop
# 10655              BOM → HYD    02:55         04:20   1h 25m    non-stop
# 10656              BLR → DEL    07:00         09:40   2h 40m    non-stop
# 10657        CCU → BOM → BLR    20:00  09:20 07 May  13h 20m      1 stop
# 10658              BLR → DEL    11:10         14:05   2h 55m    non-stop
# 10659              BLR → DEL    21:00         23:50   2h 50m    non-stop
# 10660              BLR → DEL    21:10  00:05 19 Mar   2h 55m    non-stop
# 10661        DEL → BOM → COK    13:00         19:15   6h 15m      1 stop
# 10662  CCU → BOM → GOI → BLR    09:25  05:35 25 Mar  20h 10m     2 stops
# 10663  DEL → JAI → BOM → COK    19:30  12:35 07 Jun   17h 5m     2 stops
# 10664              BLR → DEL    18:55         21:50   2h 55m    non-stop
# 10665              CCU → BLR    15:15         17:45   2h 30m    non-stop
# 10666        DEL → BOM → COK    18:15  19:00 13 Jun  24h 45m      1 stop
# 10667        BLR → BOM → DEL    22:55  20:20 13 Mar  21h 25m      1 stop
# 10668  DEL → JDH → BOM → COK    11:40         19:00   7h 20m     2 stops
# 10669        DEL → BOM → COK    08:00         19:15  11h 15m      1 stop
# 10670  CCU → IXR → DEL → BLR    05:50         23:15  17h 25m     2 stops
# 10671              BOM → HYD    21:05         22:25   1h 20m    non-stop
# 10672  DEL → AMD → BOM → COK    23:05  19:00 28 Jun  19h 55m     2 stops
# 10673  DEL → AMD → BOM → COK    13:25  04:25 28 May      15h     2 stops
# 10674        BLR → BOM → DEL    20:35  21:20 13 Mar  24h 45m      1 stop
# 10675              BOM → HYD    06:20         07:40   1h 20m    non-stop
# 10676        DEL → BOM → COK    10:20         19:00   8h 40m      1 stop
# 10677              BLR → DEL    05:55         08:35   2h 40m    non-stop
# 10678              CCU → BLR    19:55         22:25   2h 30m    non-stop
# 10679              CCU → BLR    20:45         23:20   2h 35m    non-stop
# 10680              BLR → DEL    08:20         11:20       3h    non-stop
# 10681              BLR → DEL    11:30         14:10   2h 40m    non-stop
# 10682  DEL → GOI → BOM → COK    10:55         19:15   8h 20m     2 stops
#
#                     Additional_Info  Price
# 0                           No info   3897
# 1                           No info   7662
# 2                           No info  13882
# 3                           No info   6218
# 4                           No info  13302
# 5                           No info   3873
# 6       In-flight meal not included  11087
# 7                           No info  22270
# 8       In-flight meal not included  11087
# 9                           No info   8625
# 10                          No info   8907
# 11                          No info   4174
# 12                          No info   4667
# 13      In-flight meal not included   9663
# 14                          No info   4804
# 15                          No info  14011
# 16                          No info   5830
# 17      In-flight meal not included  10262
# 18                          No info  13381
# 19      In-flight meal not included  12898
# 20                          No info  19495
# 21                          No info   6955
# 22                          No info   3943
# 23                          No info   4823
# 24      In-flight meal not included   7757
# 25                          No info  13292
# 26                          No info   8238
# 27                          No info   7682
# 28                          No info   4668
# 29                          No info   3687
# ...                             ...    ...
# 10653                       No info  14388
# 10654  No check-in baggage included   4319
# 10655                       No info   5678
# 10656                       No info   5613
# 10657   In-flight meal not included   9663
# 10658   In-flight meal not included   5769
# 10659                       No info   4668
# 10660                       No info   4878
# 10661                       No info   8372
# 10662                       No info  12352
# 10663   In-flight meal not included  11733
# 10664                       No info   4823
# 10665                       No info   4804
# 10666   In-flight meal not included  10262
# 10667   In-flight meal not included  11087
# 10668                       No info  21219
# 10669                       No info   9929
# 10670                       No info  11411
# 10671                       No info   3100
# 10672   In-flight meal not included  11150
# 10673                       No info  16704
# 10674   In-flight meal not included  11087
# 10675                       No info   3100
# 10676                       No info   9794
# 10677  No check-in baggage included   3257
# 10678                       No info   4107
# 10679                       No info   4145
# 10680                       No info   7229
# 10681                       No info  12648
# 10682                       No info  11753
#
# [10683 rows x 11 columns]

# %% [markdown]
# We have 10683 rows and 11 columns in the Train Dataset. We can see that the column Arrival Time also consists of Arrival Date in it. Hence we will split the column into three i.e Arrival_Time, Arrival_Date and Arrival_Month.

# %%
#Splitting column Arrival_Time
df[['Arrival_Time','Arrival_Date','Arrival_Month']] = df.Arrival_Time.str.split(" ",expand=True)

# %%
df
# Out:
#                  Airline Date_of_Journey    Source Destination  \
# 0                 IndiGo      24/03/2019  Banglore   New Delhi
# 1              Air India       1/05/2019   Kolkata    Banglore
# 2            Jet Airways       9/06/2019     Delhi      Cochin
# 3                 IndiGo      12/05/2019   Kolkata    Banglore
# 4                 IndiGo      01/03/2019  Banglore   New Delhi
# 5               SpiceJet      24/06/2019   Kolkata    Banglore
# 6            Jet Airways      12/03/2019  Banglore   New Delhi
# 7            Jet Airways      01/03/2019  Banglore   New Delhi
# 8            Jet Airways      12/03/2019  Banglore   New Delhi
# 9      Multiple carriers      27/05/2019     Delhi      Cochin
# 10             Air India       1/06/2019     Delhi      Cochin
# 11                IndiGo      18/04/2019   Kolkata    Banglore
# 12             Air India      24/06/2019   Chennai     Kolkata
# 13           Jet Airways       9/05/2019   Kolkata    Banglore
# 14                IndiGo      24/04/2019   Kolkata    Banglore
# 15             Air India       3/03/2019     Delhi      Cochin
# 16              SpiceJet      15/04/2019     Delhi      Cochin
# 17           Jet Airways      12/06/2019     Delhi      Cochin
# 18             Air India      12/06/2019     Delhi      Cochin
# 19           Jet Airways      27/05/2019     Delhi      Cochin
# 20                 GoAir       6/03/2019     Delhi      Cochin
# 21             Air India      21/03/2019  Banglore   New Delhi
# 22                IndiGo       3/04/2019  Banglore       Delhi
# 23                IndiGo       1/05/2019  Banglore       Delhi
# 24           Jet Airways       6/05/2019   Kolkata    Banglore
# 25           Jet Airways       9/06/2019     Delhi      Cochin
# 26                IndiGo       1/06/2019     Delhi      Cochin
# 27                 GoAir      15/05/2019     Delhi      Cochin
# 28               Vistara      18/06/2019  Banglore       Delhi
# 29               Vistara      15/06/2019   Chennai     Kolkata
# ...                  ...             ...       ...         ...
# 10653        Jet Airways       1/05/2019   Kolkata    Banglore
# 10654           SpiceJet      12/06/2019  Banglore       Delhi
# 10655        Jet Airways       3/05/2019    Mumbai   Hyderabad
# 10656            Vistara       6/04/2019  Banglore       Delhi
# 10657        Jet Airways       6/05/2019   Kolkata    Banglore
# 10658        Jet Airways      18/06/2019  Banglore       Delhi
# 10659            Vistara       1/05/2019  Banglore       Delhi
# 10660            Vistara      21/03/2019  Banglore   New Delhi
# 10661          Air India       9/05/2019     Delhi      Cochin
# 10662          Air India      24/03/2019   Kolkata    Banglore
# 10663        Jet Airways       6/06/2019     Delhi      Cochin
# 10664             IndiGo       9/04/2019  Banglore       Delhi
# 10665             IndiGo      27/04/2019   Kolkata    Banglore
# 10666        Jet Airways      12/06/2019     Delhi      Cochin
# 10667        Jet Airways      12/03/2019  Banglore   New Delhi
# 10668        Jet Airways       9/05/2019     Delhi      Cochin
# 10669          Air India      15/06/2019     Delhi      Cochin
# 10670          Air India      12/05/2019   Kolkata    Banglore
# 10671          Air India       6/06/2019    Mumbai   Hyderabad
# 10672        Jet Airways      27/06/2019     Delhi      Cochin
# 10673        Jet Airways      27/05/2019     Delhi      Cochin
# 10674        Jet Airways      12/03/2019  Banglore   New Delhi
# 10675          Air India       9/06/2019    Mumbai   Hyderabad
# 10676  Multiple carriers       1/05/2019     Delhi      Cochin
# 10677           SpiceJet      21/05/2019  Banglore       Delhi
# 10678           Air Asia       9/04/2019   Kolkata    Banglore
# 10679          Air India      27/04/2019   Kolkata    Banglore
# 10680        Jet Airways      27/04/2019  Banglore       Delhi
# 10681            Vistara      01/03/2019  Banglore   New Delhi
# 10682          Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20        01:10   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50        13:15   7h 25m     2 stops
# 2      DEL → LKO → BOM → COK    09:25        04:25      19h     2 stops
# 3            CCU → NAG → BLR    18:05        23:30   5h 25m      1 stop
# 4            BLR → NAG → DEL    16:50        21:35   4h 45m      1 stop
# 5                  CCU → BLR    09:00        11:25   2h 25m    non-stop
# 6            BLR → BOM → DEL    18:55        10:25  15h 30m      1 stop
# 7            BLR → BOM → DEL    08:00        05:05   21h 5m      1 stop
# 8            BLR → BOM → DEL    08:55        10:25  25h 30m      1 stop
# 9            DEL → BOM → COK    11:25        19:15   7h 50m      1 stop
# 10           DEL → BLR → COK    09:45        23:00  13h 15m      1 stop
# 11                 CCU → BLR    20:20        22:55   2h 35m    non-stop
# 12                 MAA → CCU    11:40        13:55   2h 15m    non-stop
# 13           CCU → BOM → BLR    21:10        09:20  12h 10m      1 stop
# 14                 CCU → BLR    17:15        19:50   2h 35m    non-stop
# 15     DEL → AMD → BOM → COK    16:40        19:15  26h 35m     2 stops
# 16           DEL → PNQ → COK    08:45        13:15   4h 30m      1 stop
# 17           DEL → BOM → COK    14:00        12:35  22h 35m      1 stop
# 18     DEL → CCU → BOM → COK    20:15        19:15      23h     2 stops
# 19           DEL → BOM → COK    16:00        12:35  20h 35m      1 stop
# 20           DEL → BOM → COK    14:10        19:20   5h 10m      1 stop
# 21           BLR → COK → DEL    22:00        13:20  15h 20m      1 stop
# 22                 BLR → DEL    04:00        06:50   2h 50m    non-stop
# 23                 BLR → DEL    18:55        21:50   2h 55m    non-stop
# 24           CCU → BOM → BLR    18:55        08:15  13h 20m      1 stop
# 25     DEL → IDR → BOM → COK    21:25        12:35  15h 10m     2 stops
# 26           DEL → LKO → COK    21:50        03:35   5h 45m      1 stop
# 27           DEL → BOM → COK    07:00        12:55   5h 55m      1 stop
# 28                 BLR → DEL    09:45        12:35   2h 50m    non-stop
# 29                 MAA → CCU    07:05        09:20   2h 15m    non-stop
# ...                      ...      ...          ...      ...         ...
# 10653        CCU → BOM → BLR    14:05        12:00  21h 55m      1 stop
# 10654              BLR → DEL    05:55        08:35   2h 40m    non-stop
# 10655              BOM → HYD    02:55        04:20   1h 25m    non-stop
# 10656              BLR → DEL    07:00        09:40   2h 40m    non-stop
# 10657        CCU → BOM → BLR    20:00        09:20  13h 20m      1 stop
# 10658              BLR → DEL    11:10        14:05   2h 55m    non-stop
# 10659              BLR → DEL    21:00        23:50   2h 50m    non-stop
# 10660              BLR → DEL    21:10        00:05   2h 55m    non-stop
# 10661        DEL → BOM → COK    13:00        19:15   6h 15m      1 stop
# 10662  CCU → BOM → GOI → BLR    09:25        05:35  20h 10m     2 stops
# 10663  DEL → JAI → BOM → COK    19:30        12:35   17h 5m     2 stops
# 10664              BLR → DEL    18:55        21:50   2h 55m    non-stop
# 10665              CCU → BLR    15:15        17:45   2h 30m    non-stop
# 10666        DEL → BOM → COK    18:15        19:00  24h 45m      1 stop
# 10667        BLR → BOM → DEL    22:55        20:20  21h 25m      1 stop
# 10668  DEL → JDH → BOM → COK    11:40        19:00   7h 20m     2 stops
# 10669        DEL → BOM → COK    08:00        19:15  11h 15m      1 stop
# 10670  CCU → IXR → DEL → BLR    05:50        23:15  17h 25m     2 stops
# 10671              BOM → HYD    21:05        22:25   1h 20m    non-stop
# 10672  DEL → AMD → BOM → COK    23:05        19:00  19h 55m     2 stops
# 10673  DEL → AMD → BOM → COK    13:25        04:25      15h     2 stops
# 10674        BLR → BOM → DEL    20:35        21:20  24h 45m      1 stop
# 10675              BOM → HYD    06:20        07:40   1h 20m    non-stop
# 10676        DEL → BOM → COK    10:20        19:00   8h 40m      1 stop
# 10677              BLR → DEL    05:55        08:35   2h 40m    non-stop
# 10678              CCU → BLR    19:55        22:25   2h 30m    non-stop
# 10679              CCU → BLR    20:45        23:20   2h 35m    non-stop
# 10680              BLR → DEL    08:20        11:20       3h    non-stop
# 10681              BLR → DEL    11:30        14:10   2h 40m    non-stop
# 10682  DEL → GOI → BOM → COK    10:55        19:15   8h 20m     2 stops
#
#                     Additional_Info  Price Arrival_Date Arrival_Month
# 0                           No info   3897           22           Mar
# 1                           No info   7662         None          None
# 2                           No info  13882           10           Jun
# 3                           No info   6218         None          None
# 4                           No info  13302         None          None
# 5                           No info   3873         None          None
# 6       In-flight meal not included  11087           13           Mar
# 7                           No info  22270           02           Mar
# 8       In-flight meal not included  11087           13           Mar
# 9                           No info   8625         None          None
# 10                          No info   8907         None          None
# 11                          No info   4174         None          None
# 12                          No info   4667         None          None
# 13      In-flight meal not included   9663           10           May
# 14                          No info   4804         None          None
# 15                          No info  14011           04           Mar
# 16                          No info   5830         None          None
# 17      In-flight meal not included  10262           13           Jun
# 18                          No info  13381           13           Jun
# 19      In-flight meal not included  12898           28           May
# 20                          No info  19495         None          None
# 21                          No info   6955           19           Mar
# 22                          No info   3943         None          None
# 23                          No info   4823         None          None
# 24      In-flight meal not included   7757           07           May
# 25                          No info  13292           10           Jun
# 26                          No info   8238           02           Jun
# 27                          No info   7682         None          None
# 28                          No info   4668         None          None
# 29                          No info   3687         None          None
# ...                             ...    ...          ...           ...
# 10653                       No info  14388           02           May
# 10654  No check-in baggage included   4319         None          None
# 10655                       No info   5678         None          None
# 10656                       No info   5613         None          None
# 10657   In-flight meal not included   9663           07           May
# 10658   In-flight meal not included   5769         None          None
# 10659                       No info   4668         None          None
# 10660                       No info   4878           19           Mar
# 10661                       No info   8372         None          None
# 10662                       No info  12352           25           Mar
# 10663   In-flight meal not included  11733           07           Jun
# 10664                       No info   4823         None          None
# 10665                       No info   4804         None          None
# 10666   In-flight meal not included  10262           13           Jun
# 10667   In-flight meal not included  11087           13           Mar
# 10668                       No info  21219         None          None
# 10669                       No info   9929         None          None
# 10670                       No info  11411         None          None
# 10671                       No info   3100         None          None
# 10672   In-flight meal not included  11150           28           Jun
# 10673                       No info  16704           28           May
# 10674   In-flight meal not included  11087           13           Mar
# 10675                       No info   3100         None          None
# 10676                       No info   9794         None          None
# 10677  No check-in baggage included   3257         None          None
# 10678                       No info   4107         None          None
# 10679                       No info   4145         None          None
# 10680                       No info   7229         None          None
# 10681                       No info  12648         None          None
# 10682                       No info  11753         None          None
#
# [10683 rows x 13 columns]

# %% [markdown]
# Now we have 13 columns in our dataset. Let's check the Null Values.

# %%
#Checking datatype of each column
df.dtypes
# Out:
# Airline            object
# Date_of_Journey    object
# Source             object
# Destination        object
# Route              object
# Dep_Time           object
# Arrival_Time       object
# Duration           object
# Total_Stops        object
# Additional_Info    object
# Price               int64
# Arrival_Date       object
# Arrival_Month      object
# dtype: object

# %% [markdown]
# As we see that the date column has string data type, hence we convert it into datetime datatye.

# %%
#Converting date column from string to datetime stamp
df['Date_of_Journey'] = pd.to_datetime(df['Date_of_Journey'])

# %%
#verifying the datatype of date_of_journey column
df.dtypes
# Out:
# Airline                    object
# Date_of_Journey    datetime64[ns]
# Source                     object
# Destination                object
# Route                      object
# Dep_Time                   object
# Arrival_Time               object
# Duration                   object
# Total_Stops                object
# Additional_Info            object
# Price                       int64
# Arrival_Date               object
# Arrival_Month              object
# dtype: object

# %% [markdown]
# The Date_Of_journey column is now converted into datetime datatype. We will now split this column into Day, Month and Year to improve performance.

# %%
#Splitting of day, month nad Year from the Date_Of_Journey column
df['Year']= df['Date_of_Journey'].dt.year
df['Month']= df['Date_of_Journey'].dt.month
df['Day']= df['Date_of_Journey'].dt.day

# %%
#Verifying the columns
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-01-05   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-09-06     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      2019-12-05   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      2019-01-03  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time Arrival_Time Duration Total_Stops Additional_Info  Price  \
# 0    22:20        01:10   2h 50m    non-stop         No info   3897
# 1    05:50        13:15   7h 25m     2 stops         No info   7662
# 2    09:25        04:25      19h     2 stops         No info  13882
# 3    18:05        23:30   5h 25m      1 stop         No info   6218
# 4    16:50        21:35   4h 45m      1 stop         No info  13302
#
#   Arrival_Date Arrival_Month  Year  Month  Day
# 0           22           Mar  2019      3   24
# 1         None          None  2019      1    5
# 2           10           Jun  2019      9    6
# 3         None          None  2019     12    5
# 4         None          None  2019      1    3

# %% [markdown]
# As we have retrieved the data from date column by splitting it, so we will drop the Date_Of_Journey column.

# %%
#Dropping column
df.drop('Date_of_Journey',axis=1,inplace=True)

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#   Arrival_Time Duration Total_Stops Additional_Info  Price Arrival_Date  \
# 0        01:10   2h 50m    non-stop         No info   3897           22
# 1        13:15   7h 25m     2 stops         No info   7662         None
# 2        04:25      19h     2 stops         No info  13882           10
# 3        23:30   5h 25m      1 stop         No info   6218         None
# 4        21:35   4h 45m      1 stop         No info  13302         None
#
#   Arrival_Month  Year  Month  Day
# 0           Mar  2019      3   24
# 1          None  2019      1    5
# 2           Jun  2019      9    6
# 3          None  2019     12    5
# 4          None  2019      1    3

# %% [markdown]
# We cannot see the date column in our dataset.

# %% [markdown]
# # Checking Null Values

# %%
#Checking Null values
df.isnull().sum()
# Out:
# Airline               0
# Source                0
# Destination           0
# Route                 1
# Dep_Time              0
# Arrival_Time          0
# Duration              0
# Total_Stops           1
# Additional_Info       0
# Price                 0
# Arrival_Date       6348
# Arrival_Month      6348
# Year                  0
# Month                 0
# Day                   0
# dtype: int64

# %% [markdown]
# The columns Arrival_Date & Arrival_Month has around 60% of Null values. Hence, we drop the columns. We also see 1 Null Value in both Route and Total Stops column which a nomial type of data. Hence, we will treat them using Simple Imputer with 'most frquent' strategy.

# %%
#Dropping columns Arrival_Date & Arrival_Month 
df.drop(['Arrival_Date','Arrival_Month'],axis=1,inplace=True)

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#   Arrival_Time Duration Total_Stops Additional_Info  Price  Year  Month  Day
# 0        01:10   2h 50m    non-stop         No info   3897  2019      3   24
# 1        13:15   7h 25m     2 stops         No info   7662  2019      1    5
# 2        04:25      19h     2 stops         No info  13882  2019      9    6
# 3        23:30   5h 25m      1 stop         No info   6218  2019     12    5
# 4        21:35   4h 45m      1 stop         No info  13302  2019      1    3

# %% [markdown]
# We can notice columns Arrival_Date & Arrival_Month have been dropped from our dataset.

# %%
#Filling the place column using simle Imputer
from sklearn.impute import SimpleImputer

imp=SimpleImputer(strategy='most_frequent')

df['Route']=imp.fit_transform(df['Route'].values.reshape(-1,1))
df['Total_Stops']=imp.fit_transform(df['Total_Stops'].values.reshape(-1,1))

df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#   Arrival_Time Duration Total_Stops Additional_Info  Price  Year  Month  Day
# 0        01:10   2h 50m    non-stop         No info   3897  2019      3   24
# 1        13:15   7h 25m     2 stops         No info   7662  2019      1    5
# 2        04:25      19h     2 stops         No info  13882  2019      9    6
# 3        23:30   5h 25m      1 stop         No info   6218  2019     12    5
# 4        21:35   4h 45m      1 stop         No info  13302  2019      1    3

# %%
#Verifying null values again
df.isnull().sum()
# Out:
# Airline            0
# Source             0
# Destination        0
# Route              0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# Price              0
# Year               0
# Month              0
# Day                0
# dtype: int64

# %%
#Visualizing null values through heatmap
import seaborn as sns
sns.heatmap(df.isnull())

# %% [markdown]
# As we cannot see any null values in our data. Hence, we proceed forward with Visualizing the data.

# %% [markdown]
# # Making DataFrame for the Nominal Data

# %%
#Copying nominal variables into a new dataframe
df_nominal=df[['Airline','Source','Destination','Total_Stops','Additional_Info','Year','Month']].copy()

# %%
#Checking columns of new nominal dataframe created
df_nominal.columns
# Out:
# Index(['Airline', 'Source', 'Destination', 'Total_Stops', 'Additional_Info',
#        'Year', 'Month'],
#       dtype='object')

# %%
#Cheking shape of new nominal dataframe
df_nominal.shape
# Out:
# (10683, 7)

# %% [markdown]
# We have 7 columns in the nominal DataFrame.

# %% [markdown]
# # Visualization of Data

# %% [markdown]
# For the nominal/categorical data we will use countplot as it will gives frequency of the columns.

# %%
#Importing Libraries for Visualization
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Using countplot for nominal data
ab=sns.countplot(x='Airline', data=df_nominal)
print(df_nominal['Airline'].value_counts())
# Out:
# Jet Airways                          3849
# IndiGo                               2053
# Air India                            1752
# Multiple carriers                    1196
# SpiceJet                              818
# Vistara                               479
# Air Asia                              319
# GoAir                                 194
# Multiple carriers Premium economy      13
# Jet Airways Business                    6
# Vistara Premium economy                 3
# Trujet                                  1
# Name: Airline, dtype: int64

# %% [markdown]
# The maximum flights flying are from Jet Airways, Indigo and Air India and least are from Trujet & Vistara Premium economy.

# %%
#Using countplot for nominal data
ab=sns.countplot(x='Source', data=df_nominal)
print(df_nominal['Source'].value_counts())
# Out:
# Delhi       4537
# Kolkata     2871
# Banglore    2197
# Mumbai       697
# Chennai      381
# Name: Source, dtype: int64

# %% [markdown]
# Most of the flights are flying from Delhi and the least are flying from Chennai.

# %%
#Using countplot for nominal data
ab=sns.countplot(x='Destination', data=df_nominal)
print(df_nominal['Destination'].value_counts())
# Out:
# Cochin       4537
# Banglore     2871
# Delhi        1265
# New Delhi     932
# Hyderabad     697
# Kolkata       381
# Name: Destination, dtype: int64

# %% [markdown]
# Majority of the flights are landing at the Cochin Airport and least are landing at the Kolkata Airport.

# %%
#Using countplot for nominal data
ab=sns.countplot(x='Total_Stops', data=df_nominal)
print(df_nominal['Total_Stops'].value_counts())
# Out:
# 1 stop      5626
# non-stop    3491
# 2 stops     1520
# 3 stops       45
# 4 stops        1
# Name: Total_Stops, dtype: int64

# %% [markdown]
# The majority flights have only one stop in between the journey and most of them are also non stop but very few flights have 3 & 4 stops.

# %%
ab=sns.countplot(x='Year', data=df_nominal)
print(df_nominal['Year'].value_counts())
# Out:
# 2019    10683
# Name: Year, dtype: int64

# %% [markdown]
# As we see that our whole dataset consists of the year 2019. This data no more serves as any importance to our dataset hence we drop the column.

# %%
#Droping the Year column from the dataset
df.drop(['Year'],axis=1,inplace=True)

# %%
ab=sns.countplot(x='Month', data=df_nominal)
print(df_nominal['Month'].value_counts())
# Out:
# 6     2536
# 3     2211
# 5     2074
# 9     1406
# 1     1075
# 12     957
# 4      424
# Name: Month, dtype: int64

# %% [markdown]
# Our flights have journey mostly in the month of June, May and March.

# %%
#Using countplot for nominal data
ab=sns.countplot(x='Additional_Info', data=df_nominal)
print(df_nominal['Additional_Info'].value_counts())
# Out:
# No info                         8345
# In-flight meal not included     1982
# No check-in baggage included     320
# 1 Long layover                    19
# Change airports                    7
# Business class                     4
# No Info                            3
# 2 Long layover                     1
# Red-eye flight                     1
# 1 Short layover                    1
# Name: Additional_Info, dtype: int64

# %% [markdown]
# As we can see that this column is mostly filled with no information so the column does not serve much importance to our dataset. Hence, we will drop the column.

# %%
#Droping the Additional_Info column from the dataset
df.drop(['Additional_Info'],axis=1,inplace=True)

# %%
#Verifying dropped column
df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#   Arrival_Time Duration Total_Stops  Price  Month  Day
# 0        01:10   2h 50m    non-stop   3897      3   24
# 1        13:15   7h 25m     2 stops   7662      1    5
# 2        04:25      19h     2 stops  13882      9    6
# 3        23:30   5h 25m      1 stop   6218     12    5
# 4        21:35   4h 45m      1 stop  13302      1    3

# %% [markdown]
# The columns have been dropped from the above dataset.

# %% [markdown]
# # Making DataFrame of the Ordinal Data

# %%
#Creating ordinal dataframe
df_ordinal=df[['Route']].copy()

# %%
#Verifying columns
df_ordinal.columns
# Out:
# Index(['Route'], dtype='object')

# %%
plt.scatter(df['Route'],df['Price'],alpha=0.5)

# %% [markdown]
# We are not able to understand and predict any conclusion out of the above graph. Hence, we move forward with other visualizations.

# %%
df.dtypes
# Out:
# Airline         object
# Source          object
# Destination     object
# Route           object
# Dep_Time        object
# Arrival_Time    object
# Duration        object
# Total_Stops     object
# Price            int64
# Month            int64
# Day              int64
# dtype: object

# %% [markdown]
# We can see that most of our data is string datatype. Hence we will first convert the data using Ordinal Encoder to visualize further.

# %% [markdown]
# # Encoding of DataFrame

# %%
#Encoding data using Ordinal Encoder
from sklearn.preprocessing import OrdinalEncoder
enc=OrdinalEncoder()

# %%
#COnverting all string values into float values
for i in df.columns:
    if df[i].dtypes=='object':
        df[i]=enc.fit_transform(df[i].values.reshape(-1,1))

# %%
#Verifying encoded data
df.head()
# Out:
#    Airline  Source  Destination  Route  Dep_Time  Arrival_Time  Duration  \
# 0      3.0     0.0          5.0   18.0     211.0          12.0     240.0
# 1      1.0     3.0          0.0   84.0      31.0         104.0     336.0
# 2      4.0     2.0          1.0  118.0      70.0          30.0     106.0
# 3      3.0     3.0          0.0   91.0     164.0         217.0     311.0
# 4      3.0     0.0          5.0   29.0     149.0         194.0     303.0
#
#    Total_Stops  Price  Month  Day
# 0          4.0   3897      3   24
# 1          1.0   7662      1    5
# 2          1.0  13882      9    6
# 3          0.0   6218     12    5
# 4          0.0  13302      1    3

# %% [markdown]
# We can see that our data has been encoded and has been converted to float values.

# %% [markdown]
# # Making DataFrame of the Continuous type of Values

# %%
#Copying our continuous data into a new dataframe
df_continuous=df[['Dep_Time', 'Arrival_Time','Duration','Price','Day']].copy()

# %%
#Verifying columns
df_continuous.columns
# Out:
# Index(['Dep_Time', 'Arrival_Time', 'Duration', 'Price', 'Day'], dtype='object')

# %% [markdown]
# # Visualizing Continuous Data

# %%
#Visualizing different columns using distplot
ncol,nrow=9,3
ab=df_continuous.columns.values
plt.figure(figsize=(20,20))
for index,i in enumerate(ab):
    ab=plt.subplot(ncol,nrow,index+1)
    sns.distplot(df[i])
    plt.title(f"plot {i}")
    plt.tight_layout()
plt.show()

# %% [markdown]
# Observations:
#
# We can see that the data is broadly scattered in all columns except for the price column.
#
# The data in price column is right skewed but it is a target variable so we don't consider the skewness of this column.
#
# The data in Dep_Time & Arrival_Time column is scattered between the range 0 and 225.
#
# The data in duration column lies is in between the range 0 and 375.
#
# In Day column, we can see that the maximum number of flights are flying between the dates 3 and 7.

# %%
#using multivariate analysis

sns.pairplot(df)

# %% [markdown]
# As most of the data in our dataset is of the object datatype so we are unable to understand the data using this analysis. Hence, we'll try using other visualization techniques to understand the data.

# %% [markdown]
# # Describe Data

# %%
#Describing final columns present in dataset
df.columns
# Out:
# Index(['Airline', 'Source', 'Destination', 'Route', 'Dep_Time', 'Arrival_Time',
#        'Duration', 'Total_Stops', 'Price', 'Month', 'Day'],
#       dtype='object')

# %%
#Defining Shape
df.shape
# Out:
# (10683, 11)

# %% [markdown]
# We finally now have 11 columns inour dataset.

# %%
#Getting data information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
# Airline         10683 non-null float64
# Source          10683 non-null float64
# Destination     10683 non-null float64
# Route           10683 non-null float64
# Dep_Time        10683 non-null float64
# Arrival_Time    10683 non-null float64
# Duration        10683 non-null float64
# Total_Stops     10683 non-null float64
# Price           10683 non-null int64
# Month           10683 non-null int64
# Day             10683 non-null int64
# dtypes: float64(8), int64(3)
# memory usage: 918.1 KB

# %% [markdown]
# There are 10683 rows and no null values in our data. Also the values in the dataset are in the form of float and int. Now, we can try understanding our data better.

# %%
#Visualizing data description
import matplotlib.pyplot as plt
plt.figure(figsize=(22,7))
sns.heatmap(df.describe(),annot=True,linewidths=0.1,linecolor='blue',fmt='0.2f')

# %% [markdown]
# Observation:
#
# The standard deviation in the Route, Dep_Time, Arrival_time, Duration and Price column is too high which means that the values in these columns are largely scattered.
#
# The standard devation of other columns is not too high which shows us a normal distribution of data and no skewness.
#
# The values of Price column which is the target variable starts from 1759 and ends at a rate 79512. The range is too high.

# %% [markdown]
# # Correlation of Columns with the Target Variable

# %%
#Plotting correlation of input features with the target Variable
plt.figure(figsize=(22,7))
sns.heatmap(df.corr(),annot=True,linewidths=0.1,linecolor='black',fmt='0.2f')

# %% [markdown]
# Observations:
#
# We dont see any high positive correlation in our data with respect to the target variable.
#
# The most negatively correlated column is that of the Total_Stops which means more the number of stops less the flight price.
#
# The most positively correlated column is the Route and the most negatively correlated is the TOtal_Stops.

# %%
#Plotting Correlation in order with the target variable
plt.figure(figsize=(22,7))
df.corr()['Price'].sort_values(ascending=False).drop(['Price']).plot(kind='bar',color='c')
plt.xlabel('Feature',fontsize=14)
plt.ylabel('column with target names',fontsize=14)
plt.title('correlation',fontsize=18)
plt.show()

# %% [markdown]
# The columns Route, Arrival_Time, Source, Month and Dep_Time are positively correlated with the Target Variable and columns Airline, Destination, Duration, Day and Total_STops are negatively correlated.

# %%
df.shape
# Out:
# (10683, 11)

# %% [markdown]
# # Checking skewness

# %%
#checking skewness
df.skew()
# Out:
# Airline         0.731095
# Source         -0.424054
# Destination     1.244169
# Route          -0.502066
# Dep_Time        0.195055
# Arrival_Time   -0.103952
# Duration       -0.213427
# Total_Stops     0.631681
# Price           1.812552
# Month           0.629540
# Day             0.367373
# dtype: float64

# %% [markdown]
# Keeping threshold +/-0.5 as the range for skewness, we do not see much skewness in our data. Only columns Airline, Destination, Price and Month show skewness wherein all the input features are of the Object datatype and Price is the Target Variable. Hence, there is no skewness found in our data.

# %% [markdown]
# # Checking Outliers

# %%
#Visualizing outliers of different variables
collist=df.columns.values
ncol=12
nrows=10
plt.figure(figsize=(ncol,5*ncol))
for i in range(1,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(df[collist[i]],color='green',orient='v')
    plt.tight_layout()

# %% [markdown]
# We can observe outliers only in the Price column which is the Target Variable, hence we dont consider the outlier present in our data.

# %% [markdown]
# # Separating the column into x & y

# %%
#Creating x & y columns 
x=df.drop('Price',axis=1)
y=df['Price']

# %% [markdown]
# Separating the columns into x & y as input featues and target variable respectively.

# %% [markdown]
# # Scaling Data Using Standard Scaler

# %%
#importing library for scaling
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings('ignore')

# %%
#Scaling our data to improve model performance
sc=StandardScaler()
x=sc.fit_transform(df)
x
# Out:
# array([[-0.41067545, -1.65844074,  2.41666505, ..., -1.12554821,
#         -0.84850298,  1.28563248],
#        [-1.26099927,  0.89005213, -0.97382594, ..., -0.30904789,
#         -1.5179928 , -0.8726517 ],
#        [ 0.01448647,  0.04055451, -0.29572775, ...,  1.03985835,
#          1.15996647, -0.7590578 ],
#        ...,
#        [ 0.01448647, -1.65844074,  0.38237045, ..., -0.40295085,
#         -0.51375808,  1.62641419],
#        [ 2.56545795, -1.65844074,  2.41666505, ...,  0.77224576,
#         -1.5179928 , -1.09983951],
#        [-1.26099927,  0.04055451, -0.29572775, ...,  0.57815073,
#          1.15996647, -0.8726517 ]])

# %% [markdown]
# Since our Target Variable has continuous values, we use Linear Regression Algorithm.

# %% [markdown]
# # Model Building

# %%
#Importing libraries to build model
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

# %%
#Finding Max accuracy at the best random state
maxAccu=0
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.22,random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    pred=lr.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print('Best accuracy is ',maxAccu," on Random_state",maxRS)
# Out:
# Best accuracy is  1.0  on Random_state 1

# %% [markdown]
# We are getting 100% accuracy on random state 1. Hence, we select random state as 1.

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=1)

# %% [markdown]
# We split our data into Training and Testing giving 80% data for Training and 20% for Testing at best random state 1. We will use linear Regression to train our model as we have a continuous tye of Target Variable.

# %%
#Code for Linear Regression
lm=LinearRegression()
lm.fit(x_train,y_train)
pred=lm.predict(x_test)

# %%
#displaying predicted and actual values
print("Predicted Happiness Score: ",pred)
print('actual Happiness Score: ',y_test)
# Out:
# Predicted Happiness Score:  [ 2753.  6309. 13731. ... 14151.  6795.  4804.]
# actual Happiness Score:  7931      2753
# 5468      6309
# 8618     13731
# 3836     13555
# 7771     10844
# 3035     14848
# 2785      5911
# 4228      9838
# 9740      8610
# 5815      4990
# 691       6093
# 5402      9968
# 4770      5883
# 5758      6985
# 1893      3749
# 5980     21571
# 8943      3841
# 5510     16736
# 649       4667
# 9080      4878
# 4161     14151
# 9400      3597
# 1930     13376
# 5293     22270
# 7219      9794
# 6916     10539
# 8082     10406
# 9782     13994
# 10131     7189
# 5339     10651
#          ...
# 7715      7064
# 9465      8372
# 2481     12599
# 5821     12284
# 2932      5911
# 8233     13587
# 9100      5883
# 1148     15129
# 2430     12373
# 2711     14109
# 343      15965
# 4611     10844
# 3908      8066
# 6029     13292
# 4882      3873
# 5395     10262
# 4582     14815
# 6469     15129
# 5461      4483
# 7122      7229
# 3614     17732
# 192       6412
# 6783     11467
# 2372      8099
# 3571      8907
# 4474      9581
# 7367      3543
# 10357    14151
# 1267      6795
# 5930      4804
# Name: Price, Length: 2137, dtype: int64

# %% [markdown]
# Let's check the Training accuracy and see how well we have trained our model.

# %%
#training score
lm.score(x_train,y_train)
# Out:
# 1.0

# %% [markdown]
# We are obtaining 100% training accuracy for our Model. Let's try finding errors.

# %%
#Finding Errors
print('error:')
print('Mean absolute error:',mean_absolute_error(y_test,pred))
print('Mean squared error:',mean_squared_error(y_test,pred))

print('Root Mean squared error:',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# error:
# Mean absolute error: 2.8178588771354972e-12
# Mean squared error: 1.3671124031240235e-23
# Root Mean squared error: 3.6974483135319466e-12

# %% [markdown]
# We can observe the error rate of our model to be very less. Let's check the accuracy score to check the performance of our model.

# %%
print(r2_score(y_test,pred))
# Out:
# 1.0

# %% [markdown]
# We are obtaining our r2 score as 100% which can also be due to overfitting or underfitting problems. Hence, we will use Cross Validation to train the model better.

# %% [markdown]
# # Cross Validation of The Model

# %%
#Finding best cv score at a particular cv
pred_train=lr.predict(x_train)
pred_test=lr.predict(x_test)
train_accuracy=r2_score(y_train,pred_train)
test_accuracy=r2_score(y_test,pred_test)

from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(lr,x,y,cv=j)
    cv_mean=cv_score.mean()
    print(f"At cross fold {j} the cv score is {cv_mean} and r2 score for training is {train_accuracy} and accuracy for the testing is {test_accuracy}")
    print("\n")
# Out:
# At cross fold 2 the cv score is 1.0 and r2 score for training is 1.0 and accuracy for the testing is 1.0
#
#
# At cross fold 3 the cv score is 1.0 and r2 score for training is 1.0 and accuracy for the testing is 1.0
#
#
# At cross fold 4 the cv score is 1.0 and r2 score for training is 1.0 and accuracy for the testing is 1.0
#
#
# At cross fold 5 the cv score is 1.0 and r2 score for training is 1.0 and accuracy for the testing is 1.0
#
#
# At cross fold 6 the cv score is 1.0 and r2 score for training is 1.0 and accuracy for the testing is 1.0
#
#
# At cross fold 7 the cv score is 1.0 and r2 score for training is 1.0 and accuracy for the testing is 1.0
#
#
# At cross fold 8 the cv score is 1.0 and r2 score for training is 1.0 and accuracy for the testing is 1.0
#
#
# At cross fold 9 the cv score is 1.0 and r2 score for training is 1.0 and accuracy for the testing is 1.0

# %% [markdown]
# As there is no difference in the cv score at any cv cross fold. Hence, we will randomly select the cv at 5.

# %% [markdown]
# Here we have handled the problem or overfitting and underfitting by checking the training and testing score. Let's try checking if we are covering all the points to attain accuracy by Visualizing it.

# %%
#Code for checking linear Regression points with target variale
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=pred_test,color='r')
plt.plot(y_test,y_test,color='b')
plt.xlabel('Actual charges',fontsize=14)
plt.ylabel('Predicted charges',fontsize=14)
plt.title('Linear Regression',fontsize=18)
plt.show()

# %% [markdown]
# The Best Fit line is covering almost all the datapoints which shows good fit of our model.

# %% [markdown]
# # Regularization

# %%
#Importing Libraries for hyper parameter tuning 
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import warnings
warnings.filterwarnings('ignore')

# %%
#Using ElasticNet Regression for our Model to solve overfitting and underfitting
from sklearn.linear_model import ElasticNet

parameters={'alpha':[.0001,.001,.01,.1,1,10],'random_state':list(range(0,10))}
en=ElasticNet()
clf=GridSearchCV(en,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'alpha': 0.0001, 'random_state': 0}

# %%
#Code for ElasticNet Regression
en=ElasticNet(alpha=0.0001,random_state=0)
en.fit(x_train,y_train)
en.score(x_train,y_train)
pred_en=en.predict(x_test)

enn=r2_score(y_test,pred_en)
enn
# Out:
# 0.999999991095241

# %% [markdown]
# The accuracy that we get after using ElasticNet Regression is 99.99%

# %% [markdown]
# # Ensemble Techniques

# %%
#Finding best Parameters for Ensemble Techniques
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import AdaBoostRegressor

parameters={'random_state':list(range(0,10))}
ab=AdaBoostRegressor()
clf=GridSearchCV(ab,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'random_state': 0}

# %%
#Code for Ada Boost Regressor
ab=AdaBoostRegressor(random_state=0, n_estimators=100)
ab.fit(x_train,y_train)
ab.score(x_train,y_train)
pred_y=ab.predict(x_test)

abs=r2_score(y_test,pred_y)
print('R2 score: ',abs*100)
# Out:
# R2 score:  98.21093210657594

# %%
#Finding the Cv score of the model
abscore=cross_val_score(ab,x,y,cv=5)
abc=abscore.mean()
print("Cross Val Score: ",abc*100)
# Out:
# Cross Val Score:  97.66057338709878

# %% [markdown]
# After solving all the overfitting and underfitting problems using different testing techniques, We get our best r2 score as 98.21% and cv score at 97.70%. Hence, we will now save our best model.

# %% [markdown]
# # Saving The Best Model

# %%
#Saving the best model
import pickle
filename='Flight.pkl'
pickle.dump(ab,open(filename,'wb'))

# %% [markdown]
# # Testing Dataset

# %% [markdown]
# # Data Description

# %% [markdown]
# The Testing Data consists of two files Test and Sample in which the Test file consists of all the Input Features and the sample File consists of the Target Variable.

# %% [markdown]
# # Importing Dataset

# %%
#Importing Libraries
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
# Importing Training Dataset
df=pd.read_excel('Test_set.xlsx')
hf=pd.read_excel('Sample.xlsx')
#Visualizing first 5 rows of Test dataset
df.head()
# Out:
#              Airline Date_of_Journey    Source Destination            Route  \
# 0        Jet Airways       6/06/2019     Delhi      Cochin  DEL → BOM → COK
# 1             IndiGo      12/05/2019   Kolkata    Banglore  CCU → MAA → BLR
# 2        Jet Airways      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 3  Multiple carriers      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 4           Air Asia      24/06/2019  Banglore       Delhi        BLR → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops              Additional_Info
# 0    17:30  04:25 07 Jun  10h 55m      1 stop                      No info
# 1    06:20         10:20       4h      1 stop                      No info
# 2    19:15  19:00 22 May  23h 45m      1 stop  In-flight meal not included
# 3    08:00         21:00      13h      1 stop                      No info
# 4    23:55  02:45 25 Jun   2h 50m    non-stop                      No info

# %%
#Visualizing first 5 rows of Sample dataset
hf.head()
# Out:
#    Price
# 0  15998
# 1  16612
# 2  25572
# 3  25778
# 4  16934

# %%
#Checking columns in dataframe
df.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info'],
#       dtype='object')

# %%
#CHecking shape of dataframe
df.shape
# Out:
# (2671, 10)

# %% [markdown]
# Initially, we have 2671 rows and 10 columns in the test dataset.

# %% [markdown]
# We can see that the column Arrival Time also consists of Arrival Date in it. Hence we will split the column into three i.e Arrival_Time, Arrival_Date and Arrival_Month.

# %%
#Splitting column Arrival_Time
df[['Arrival_Time','Arrival_Date','Arrival_Month']] = df.Arrival_Time.str.split(" ",expand=True)

# %%
df
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 0           Jet Airways       6/06/2019     Delhi      Cochin
# 1                IndiGo      12/05/2019   Kolkata    Banglore
# 2           Jet Airways      21/05/2019     Delhi      Cochin
# 3     Multiple carriers      21/05/2019     Delhi      Cochin
# 4              Air Asia      24/06/2019  Banglore       Delhi
# 5           Jet Airways      12/06/2019     Delhi      Cochin
# 6             Air India      12/03/2019  Banglore   New Delhi
# 7                IndiGo       1/05/2019   Kolkata    Banglore
# 8                IndiGo      15/03/2019   Kolkata    Banglore
# 9           Jet Airways      18/05/2019   Kolkata    Banglore
# 10          Jet Airways      21/03/2019     Delhi      Cochin
# 11               IndiGo      15/06/2019     Delhi      Cochin
# 12    Multiple carriers      15/05/2019     Delhi      Cochin
# 13          Jet Airways      12/03/2019  Banglore   New Delhi
# 14          Jet Airways       3/06/2019     Delhi      Cochin
# 15          Jet Airways      06/03/2019  Banglore   New Delhi
# 16    Multiple carriers       6/06/2019     Delhi      Cochin
# 17              Vistara      24/03/2019   Kolkata    Banglore
# 18          Jet Airways      12/06/2019     Delhi      Cochin
# 19          Jet Airways      12/03/2019  Banglore   New Delhi
# 20               IndiGo       6/03/2019     Delhi      Cochin
# 21          Jet Airways       9/05/2019   Kolkata    Banglore
# 22          Jet Airways      18/03/2019  Banglore   New Delhi
# 23          Jet Airways       9/05/2019     Delhi      Cochin
# 24            Air India       6/04/2019  Banglore       Delhi
# 25          Jet Airways      21/03/2019     Delhi      Cochin
# 26               IndiGo      15/05/2019   Kolkata    Banglore
# 27          Jet Airways      21/05/2019     Delhi      Cochin
# 28          Jet Airways       6/06/2019     Delhi      Cochin
# 29    Multiple carriers       1/06/2019     Delhi      Cochin
# ...                 ...             ...       ...         ...
# 2641  Multiple carriers       9/05/2019     Delhi      Cochin
# 2642        Jet Airways      21/05/2019     Delhi      Cochin
# 2643          Air India       6/06/2019     Delhi      Cochin
# 2644  Multiple carriers       3/06/2019     Delhi      Cochin
# 2645        Jet Airways      12/03/2019  Banglore   New Delhi
# 2646        Jet Airways      18/05/2019     Delhi      Cochin
# 2647          Air India       1/05/2019   Kolkata    Banglore
# 2648             IndiGo       1/04/2019     Delhi      Cochin
# 2649           SpiceJet       6/05/2019  Banglore       Delhi
# 2650          Air India       9/05/2019   Kolkata    Banglore
# 2651        Jet Airways       6/06/2019   Kolkata    Banglore
# 2652        Jet Airways      12/03/2019  Banglore   New Delhi
# 2653        Jet Airways      18/05/2019   Kolkata    Banglore
# 2654          Air India       3/03/2019     Delhi      Cochin
# 2655  Multiple carriers      24/06/2019     Delhi      Cochin
# 2656        Jet Airways      12/05/2019   Kolkata    Banglore
# 2657  Multiple carriers       6/06/2019     Delhi      Cochin
# 2658        Jet Airways      15/06/2019     Delhi      Cochin
# 2659        Jet Airways      15/06/2019     Delhi      Cochin
# 2660          Air India      12/03/2019    Mumbai   Hyderabad
# 2661        Jet Airways      27/03/2019     Delhi      Cochin
# 2662          Air India      21/05/2019    Mumbai   Hyderabad
# 2663              GoAir      12/05/2019   Kolkata    Banglore
# 2664  Multiple carriers      15/06/2019     Delhi      Cochin
# 2665           SpiceJet      21/06/2019    Mumbai   Hyderabad
# 2666          Air India       6/06/2019   Kolkata    Banglore
# 2667             IndiGo      27/03/2019   Kolkata    Banglore
# 2668        Jet Airways       6/03/2019     Delhi      Cochin
# 2669          Air India       6/03/2019     Delhi      Cochin
# 2670  Multiple carriers      15/06/2019     Delhi      Cochin
#
#                       Route Dep_Time Arrival_Time Duration Total_Stops  \
# 0           DEL → BOM → COK    17:30        04:25  10h 55m      1 stop
# 1           CCU → MAA → BLR    06:20        10:20       4h      1 stop
# 2           DEL → BOM → COK    19:15        19:00  23h 45m      1 stop
# 3           DEL → BOM → COK    08:00        21:00      13h      1 stop
# 4                 BLR → DEL    23:55        02:45   2h 50m    non-stop
# 5           DEL → BOM → COK    18:15        12:35  18h 20m      1 stop
# 6           BLR → TRV → DEL    07:30        22:35   15h 5m      1 stop
# 7           CCU → HYD → BLR    15:15        20:30   5h 15m      1 stop
# 8                 CCU → BLR    10:10        12:55   2h 45m    non-stop
# 9           CCU → BOM → BLR    16:30        22:35    6h 5m      1 stop
# 10    DEL → MAA → BOM → COK    13:55        18:50  28h 55m     2 stops
# 11          DEL → HYD → COK    06:50        16:10   9h 20m      1 stop
# 12          DEL → BOM → COK    09:00        19:15  10h 15m      1 stop
# 13          BLR → BOM → DEL    05:45        10:25   4h 40m      1 stop
# 14          DEL → BOM → COK    19:15        12:35  17h 20m      1 stop
# 15          BLR → BOM → DEL    21:25        08:15  10h 50m      1 stop
# 16          DEL → HYD → COK    13:15        22:30   9h 15m      1 stop
# 17          CCU → DEL → BLR    09:55        22:10  12h 15m      1 stop
# 18          DEL → BOM → COK    19:15        04:25   9h 10m      1 stop
# 19          BLR → BOM → DEL    22:55        08:15   9h 20m      1 stop
# 20          DEL → BOM → COK    10:45        01:35  14h 50m      1 stop
# 21          CCU → BOM → BLR    20:00        10:05   14h 5m      1 stop
# 22          BLR → BOM → DEL    21:25        09:00  11h 35m      1 stop
# 23    DEL → JAI → BOM → COK    05:30        19:00  13h 30m     2 stops
# 24                BLR → DEL    21:05        23:55   2h 50m    non-stop
# 25          DEL → BOM → COK    16:00        04:25  12h 25m      1 stop
# 26                CCU → BLR    15:15        17:45   2h 30m    non-stop
# 27          DEL → BOM → COK    17:30        19:00  25h 30m      1 stop
# 28          DEL → BOM → COK    09:00        04:25  19h 25m      1 stop
# 29          DEL → BOM → COK    14:00        21:00       7h      1 stop
# ...                     ...      ...          ...      ...         ...
# 2641        DEL → BOM → COK    14:00        01:30  11h 30m      1 stop
# 2642        DEL → BOM → COK    22:50        12:35  13h 45m      1 stop
# 2643  DEL → HYD → MAA → COK    09:45        09:25  23h 40m     2 stops
# 2644        DEL → BOM → COK    07:30        19:00  11h 30m      1 stop
# 2645        BLR → BOM → DEL    22:55        08:15   9h 20m      1 stop
# 2646  DEL → AMD → BOM → COK    23:05        04:25  29h 20m     2 stops
# 2647  CCU → GAU → DEL → BLR    16:45        08:55  16h 10m     2 stops
# 2648              DEL → COK    21:05        00:20   3h 15m    non-stop
# 2649              BLR → DEL    05:55        08:35   2h 40m    non-stop
# 2650  CCU → IXR → DEL → BLR    05:50        08:55   27h 5m     2 stops
# 2651        CCU → DEL → BLR    09:35        22:05  12h 30m      1 stop
# 2652        BLR → BOM → DEL    22:55        13:15  14h 20m      1 stop
# 2653        CCU → BOM → BLR    16:30        22:35    6h 5m      1 stop
# 2654        DEL → BOM → COK    07:00        07:40  24h 40m      1 stop
# 2655        DEL → BOM → COK    11:40        21:00   9h 20m      1 stop
# 2656        CCU → BOM → BLR    21:10        09:20  12h 10m      1 stop
# 2657        DEL → BOM → COK    04:55        19:15  14h 20m      1 stop
# 2658        DEL → BOM → COK    21:50        19:00  21h 10m      1 stop
# 2659  DEL → BHO → BOM → COK    05:30        12:35    7h 5m     2 stops
# 2660  BOM → GOI → PNQ → HYD    16:50        16:55       5m     2 stops
# 2661  DEL → AMD → BOM → COK    19:10        04:25  33h 15m     2 stops
# 2662              BOM → HYD    13:55        15:25   1h 30m    non-stop
# 2663        CCU → BOM → BLR    23:30        07:45   8h 15m      1 stop
# 2664        DEL → BOM → COK    15:15        01:30  10h 15m      1 stop
# 2665              BOM → HYD    22:45        00:15   1h 30m    non-stop
# 2666        CCU → DEL → BLR    20:30        20:25  23h 55m      1 stop
# 2667              CCU → BLR    14:20        16:55   2h 35m    non-stop
# 2668        DEL → BOM → COK    21:50        04:25   6h 35m      1 stop
# 2669        DEL → BOM → COK    04:00        19:15  15h 15m      1 stop
# 2670        DEL → BOM → COK    04:55        19:15  14h 20m      1 stop
#
#                    Additional_Info Arrival_Date Arrival_Month
# 0                          No info           07           Jun
# 1                          No info         None          None
# 2      In-flight meal not included           22           May
# 3                          No info         None          None
# 4                          No info           25           Jun
# 5      In-flight meal not included           13           Jun
# 6                          No info         None          None
# 7                          No info         None          None
# 8                          No info         None          None
# 9                          No info         None          None
# 10     In-flight meal not included           22           Mar
# 11                         No info         None          None
# 12                         No info         None          None
# 13                         No info         None          None
# 14     In-flight meal not included           04           Jun
# 15                         No info           07           Mar
# 16                         No info         None          None
# 17                         No info         None          None
# 18     In-flight meal not included           13           Jun
# 19                         No info           13           Mar
# 20                         No info           07           Mar
# 21     In-flight meal not included           10           May
# 22     In-flight meal not included           16           Mar
# 23     In-flight meal not included         None          None
# 24                         No info         None          None
# 25     In-flight meal not included           22           Mar
# 26                         No info         None          None
# 27                         No info           22           May
# 28     In-flight meal not included           07           Jun
# 29                         No info         None          None
# ...                            ...          ...           ...
# 2641                       No info           10           May
# 2642   In-flight meal not included           22           May
# 2643                       No info           07           Jun
# 2644                       No info         None          None
# 2645   In-flight meal not included           13           Mar
# 2646                       No info           20           May
# 2647                       No info           02           May
# 2648                       No info           02           Apr
# 2649  No check-in baggage included         None          None
# 2650                       No info           10           May
# 2651   In-flight meal not included         None          None
# 2652                       No info           13           Mar
# 2653   In-flight meal not included         None          None
# 2654                       No info           04           Mar
# 2655   In-flight meal not included         None          None
# 2656   In-flight meal not included           13           May
# 2657                       No info         None          None
# 2658   In-flight meal not included           16           Jun
# 2659   In-flight meal not included         None          None
# 2660                       No info         None          None
# 2661                       No info           29           Mar
# 2662                       No info         None          None
# 2663                       No info           13           May
# 2664                       No info           16           Jun
# 2665  No check-in baggage included           22           Jun
# 2666                       No info           07           Jun
# 2667                       No info         None          None
# 2668                       No info           07           Mar
# 2669                       No info         None          None
# 2670                       No info         None          None
#
# [2671 rows x 12 columns]

# %% [markdown]
# Now we have 12 columns in our dataset. Let's check the Null Values.

# %%
#Checking datatype of each column
df.dtypes
# Out:
# Airline            object
# Date_of_Journey    object
# Source             object
# Destination        object
# Route              object
# Dep_Time           object
# Arrival_Time       object
# Duration           object
# Total_Stops        object
# Additional_Info    object
# Arrival_Date       object
# Arrival_Month      object
# dtype: object

# %% [markdown]
# As we see that the date column has string data type, hence we will convert it into datetime datatye.

# %%
#Converting date column from string to datetime stamp
df['Date_of_Journey'] = pd.to_datetime(df['Date_of_Journey'])

# %%
#verifying the datatype of date_of_journey column
df.dtypes
# Out:
# Airline                    object
# Date_of_Journey    datetime64[ns]
# Source                     object
# Destination                object
# Route                      object
# Dep_Time                   object
# Arrival_Time               object
# Duration                   object
# Total_Stops                object
# Additional_Info            object
# Arrival_Date               object
# Arrival_Month              object
# dtype: object

# %% [markdown]
# The Date_Of_journey column is now converted into datetime datatype. We will now split this column into Day, Month and Year to improve performance.

# %%
#Splitting of day, month nad Year from the Date_Of_Journey column
df['Year']= df['Date_of_Journey'].dt.year
df['Month']= df['Date_of_Journey'].dt.month
df['Day']= df['Date_of_Journey'].dt.day

# %%
#Verifying the columns
df.head()
# Out:
#              Airline Date_of_Journey    Source Destination            Route  \
# 0        Jet Airways      2019-06-06     Delhi      Cochin  DEL → BOM → COK
# 1             IndiGo      2019-12-05   Kolkata    Banglore  CCU → MAA → BLR
# 2        Jet Airways      2019-05-21     Delhi      Cochin  DEL → BOM → COK
# 3  Multiple carriers      2019-05-21     Delhi      Cochin  DEL → BOM → COK
# 4           Air Asia      2019-06-24  Banglore       Delhi        BLR → DEL
#
#   Dep_Time Arrival_Time Duration Total_Stops              Additional_Info  \
# 0    17:30        04:25  10h 55m      1 stop                      No info
# 1    06:20        10:20       4h      1 stop                      No info
# 2    19:15        19:00  23h 45m      1 stop  In-flight meal not included
# 3    08:00        21:00      13h      1 stop                      No info
# 4    23:55        02:45   2h 50m    non-stop                      No info
#
#   Arrival_Date Arrival_Month  Year  Month  Day
# 0           07           Jun  2019      6    6
# 1         None          None  2019     12    5
# 2           22           May  2019      5   21
# 3         None          None  2019      5   21
# 4           25           Jun  2019      6   24

# %% [markdown]
# As we have retrieved the data from date column by splitting it, so we will drop the Date_Of_Journey column.

# %%
#Dropping column
df.drop('Date_of_Journey',axis=1,inplace=True)

# %%
df.head()
# Out:
#              Airline    Source Destination            Route Dep_Time  \
# 0        Jet Airways     Delhi      Cochin  DEL → BOM → COK    17:30
# 1             IndiGo   Kolkata    Banglore  CCU → MAA → BLR    06:20
# 2        Jet Airways     Delhi      Cochin  DEL → BOM → COK    19:15
# 3  Multiple carriers     Delhi      Cochin  DEL → BOM → COK    08:00
# 4           Air Asia  Banglore       Delhi        BLR → DEL    23:55
#
#   Arrival_Time Duration Total_Stops              Additional_Info Arrival_Date  \
# 0        04:25  10h 55m      1 stop                      No info           07
# 1        10:20       4h      1 stop                      No info         None
# 2        19:00  23h 45m      1 stop  In-flight meal not included           22
# 3        21:00      13h      1 stop                      No info         None
# 4        02:45   2h 50m    non-stop                      No info           25
#
#   Arrival_Month  Year  Month  Day
# 0           Jun  2019      6    6
# 1          None  2019     12    5
# 2           May  2019      5   21
# 3          None  2019      5   21
# 4           Jun  2019      6   24

# %% [markdown]
# We cannot see the date column in our dataset.

# %% [markdown]
# # Checking Null Values

# %%
#Checking Null values
df.isnull().sum()
# Out:
# Airline               0
# Source                0
# Destination           0
# Route                 0
# Dep_Time              0
# Arrival_Time          0
# Duration              0
# Total_Stops           0
# Additional_Info       0
# Arrival_Date       1605
# Arrival_Month      1605
# Year                  0
# Month                 0
# Day                   0
# dtype: int64

# %% [markdown]
# The columns Arrival_Date & Arrival_Month has around 60% of Null values. Hence, we drop the columns. We also see 1 Null Value in both Route and Total Stops column which a nomial type of data. Hence, we will treat them using Simple Imputer with 'most frquent' strategy.

# %%
#Dropping columns Arrival_Date & Arrival_Month 
df.drop(['Arrival_Date','Arrival_Month'],axis=1,inplace=True)

# %%
df.head()
# Out:
#              Airline    Source Destination            Route Dep_Time  \
# 0        Jet Airways     Delhi      Cochin  DEL → BOM → COK    17:30
# 1             IndiGo   Kolkata    Banglore  CCU → MAA → BLR    06:20
# 2        Jet Airways     Delhi      Cochin  DEL → BOM → COK    19:15
# 3  Multiple carriers     Delhi      Cochin  DEL → BOM → COK    08:00
# 4           Air Asia  Banglore       Delhi        BLR → DEL    23:55
#
#   Arrival_Time Duration Total_Stops              Additional_Info  Year  Month  \
# 0        04:25  10h 55m      1 stop                      No info  2019      6
# 1        10:20       4h      1 stop                      No info  2019     12
# 2        19:00  23h 45m      1 stop  In-flight meal not included  2019      5
# 3        21:00      13h      1 stop                      No info  2019      5
# 4        02:45   2h 50m    non-stop                      No info  2019      6
#
#    Day
# 0    6
# 1    5
# 2   21
# 3   21
# 4   24

# %% [markdown]
# We can notice columns Arrival_Date & Arrival_Month have been dropped from our dataset.

# %%
#Verifying null values again
df.isnull().sum()
# Out:
# Airline            0
# Source             0
# Destination        0
# Route              0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# Year               0
# Month              0
# Day                0
# dtype: int64

# %%
#Visualizing null values through heatmap
import seaborn as sns
sns.heatmap(df.isnull())

# %% [markdown]
# As we cannot see any null values in our data. Hence, we proceed forward with Visualizing the data.

# %% [markdown]
# # Joining Two DataFrames

# %%
af=pd.concat([df,hf],axis=1)
af
# Out:
#                 Airline    Source Destination                  Route Dep_Time  \
# 0           Jet Airways     Delhi      Cochin        DEL → BOM → COK    17:30
# 1                IndiGo   Kolkata    Banglore        CCU → MAA → BLR    06:20
# 2           Jet Airways     Delhi      Cochin        DEL → BOM → COK    19:15
# 3     Multiple carriers     Delhi      Cochin        DEL → BOM → COK    08:00
# 4              Air Asia  Banglore       Delhi              BLR → DEL    23:55
# 5           Jet Airways     Delhi      Cochin        DEL → BOM → COK    18:15
# 6             Air India  Banglore   New Delhi        BLR → TRV → DEL    07:30
# 7                IndiGo   Kolkata    Banglore        CCU → HYD → BLR    15:15
# 8                IndiGo   Kolkata    Banglore              CCU → BLR    10:10
# 9           Jet Airways   Kolkata    Banglore        CCU → BOM → BLR    16:30
# 10          Jet Airways     Delhi      Cochin  DEL → MAA → BOM → COK    13:55
# 11               IndiGo     Delhi      Cochin        DEL → HYD → COK    06:50
# 12    Multiple carriers     Delhi      Cochin        DEL → BOM → COK    09:00
# 13          Jet Airways  Banglore   New Delhi        BLR → BOM → DEL    05:45
# 14          Jet Airways     Delhi      Cochin        DEL → BOM → COK    19:15
# 15          Jet Airways  Banglore   New Delhi        BLR → BOM → DEL    21:25
# 16    Multiple carriers     Delhi      Cochin        DEL → HYD → COK    13:15
# 17              Vistara   Kolkata    Banglore        CCU → DEL → BLR    09:55
# 18          Jet Airways     Delhi      Cochin        DEL → BOM → COK    19:15
# 19          Jet Airways  Banglore   New Delhi        BLR → BOM → DEL    22:55
# 20               IndiGo     Delhi      Cochin        DEL → BOM → COK    10:45
# 21          Jet Airways   Kolkata    Banglore        CCU → BOM → BLR    20:00
# 22          Jet Airways  Banglore   New Delhi        BLR → BOM → DEL    21:25
# 23          Jet Airways     Delhi      Cochin  DEL → JAI → BOM → COK    05:30
# 24            Air India  Banglore       Delhi              BLR → DEL    21:05
# 25          Jet Airways     Delhi      Cochin        DEL → BOM → COK    16:00
# 26               IndiGo   Kolkata    Banglore              CCU → BLR    15:15
# 27          Jet Airways     Delhi      Cochin        DEL → BOM → COK    17:30
# 28          Jet Airways     Delhi      Cochin        DEL → BOM → COK    09:00
# 29    Multiple carriers     Delhi      Cochin        DEL → BOM → COK    14:00
# ...                 ...       ...         ...                    ...      ...
# 2641  Multiple carriers     Delhi      Cochin        DEL → BOM → COK    14:00
# 2642        Jet Airways     Delhi      Cochin        DEL → BOM → COK    22:50
# 2643          Air India     Delhi      Cochin  DEL → HYD → MAA → COK    09:45
# 2644  Multiple carriers     Delhi      Cochin        DEL → BOM → COK    07:30
# 2645        Jet Airways  Banglore   New Delhi        BLR → BOM → DEL    22:55
# 2646        Jet Airways     Delhi      Cochin  DEL → AMD → BOM → COK    23:05
# 2647          Air India   Kolkata    Banglore  CCU → GAU → DEL → BLR    16:45
# 2648             IndiGo     Delhi      Cochin              DEL → COK    21:05
# 2649           SpiceJet  Banglore       Delhi              BLR → DEL    05:55
# 2650          Air India   Kolkata    Banglore  CCU → IXR → DEL → BLR    05:50
# 2651        Jet Airways   Kolkata    Banglore        CCU → DEL → BLR    09:35
# 2652        Jet Airways  Banglore   New Delhi        BLR → BOM → DEL    22:55
# 2653        Jet Airways   Kolkata    Banglore        CCU → BOM → BLR    16:30
# 2654          Air India     Delhi      Cochin        DEL → BOM → COK    07:00
# 2655  Multiple carriers     Delhi      Cochin        DEL → BOM → COK    11:40
# 2656        Jet Airways   Kolkata    Banglore        CCU → BOM → BLR    21:10
# 2657  Multiple carriers     Delhi      Cochin        DEL → BOM → COK    04:55
# 2658        Jet Airways     Delhi      Cochin        DEL → BOM → COK    21:50
# 2659        Jet Airways     Delhi      Cochin  DEL → BHO → BOM → COK    05:30
# 2660          Air India    Mumbai   Hyderabad  BOM → GOI → PNQ → HYD    16:50
# 2661        Jet Airways     Delhi      Cochin  DEL → AMD → BOM → COK    19:10
# 2662          Air India    Mumbai   Hyderabad              BOM → HYD    13:55
# 2663              GoAir   Kolkata    Banglore        CCU → BOM → BLR    23:30
# 2664  Multiple carriers     Delhi      Cochin        DEL → BOM → COK    15:15
# 2665           SpiceJet    Mumbai   Hyderabad              BOM → HYD    22:45
# 2666          Air India   Kolkata    Banglore        CCU → DEL → BLR    20:30
# 2667             IndiGo   Kolkata    Banglore              CCU → BLR    14:20
# 2668        Jet Airways     Delhi      Cochin        DEL → BOM → COK    21:50
# 2669          Air India     Delhi      Cochin        DEL → BOM → COK    04:00
# 2670  Multiple carriers     Delhi      Cochin        DEL → BOM → COK    04:55
#
#      Arrival_Time Duration Total_Stops               Additional_Info  Year  \
# 0           04:25  10h 55m      1 stop                       No info  2019
# 1           10:20       4h      1 stop                       No info  2019
# 2           19:00  23h 45m      1 stop   In-flight meal not included  2019
# 3           21:00      13h      1 stop                       No info  2019
# 4           02:45   2h 50m    non-stop                       No info  2019
# 5           12:35  18h 20m      1 stop   In-flight meal not included  2019
# 6           22:35   15h 5m      1 stop                       No info  2019
# 7           20:30   5h 15m      1 stop                       No info  2019
# 8           12:55   2h 45m    non-stop                       No info  2019
# 9           22:35    6h 5m      1 stop                       No info  2019
# 10          18:50  28h 55m     2 stops   In-flight meal not included  2019
# 11          16:10   9h 20m      1 stop                       No info  2019
# 12          19:15  10h 15m      1 stop                       No info  2019
# 13          10:25   4h 40m      1 stop                       No info  2019
# 14          12:35  17h 20m      1 stop   In-flight meal not included  2019
# 15          08:15  10h 50m      1 stop                       No info  2019
# 16          22:30   9h 15m      1 stop                       No info  2019
# 17          22:10  12h 15m      1 stop                       No info  2019
# 18          04:25   9h 10m      1 stop   In-flight meal not included  2019
# 19          08:15   9h 20m      1 stop                       No info  2019
# 20          01:35  14h 50m      1 stop                       No info  2019
# 21          10:05   14h 5m      1 stop   In-flight meal not included  2019
# 22          09:00  11h 35m      1 stop   In-flight meal not included  2019
# 23          19:00  13h 30m     2 stops   In-flight meal not included  2019
# 24          23:55   2h 50m    non-stop                       No info  2019
# 25          04:25  12h 25m      1 stop   In-flight meal not included  2019
# 26          17:45   2h 30m    non-stop                       No info  2019
# 27          19:00  25h 30m      1 stop                       No info  2019
# 28          04:25  19h 25m      1 stop   In-flight meal not included  2019
# 29          21:00       7h      1 stop                       No info  2019
# ...           ...      ...         ...                           ...   ...
# 2641        01:30  11h 30m      1 stop                       No info  2019
# 2642        12:35  13h 45m      1 stop   In-flight meal not included  2019
# 2643        09:25  23h 40m     2 stops                       No info  2019
# 2644        19:00  11h 30m      1 stop                       No info  2019
# 2645        08:15   9h 20m      1 stop   In-flight meal not included  2019
# 2646        04:25  29h 20m     2 stops                       No info  2019
# 2647        08:55  16h 10m     2 stops                       No info  2019
# 2648        00:20   3h 15m    non-stop                       No info  2019
# 2649        08:35   2h 40m    non-stop  No check-in baggage included  2019
# 2650        08:55   27h 5m     2 stops                       No info  2019
# 2651        22:05  12h 30m      1 stop   In-flight meal not included  2019
# 2652        13:15  14h 20m      1 stop                       No info  2019
# 2653        22:35    6h 5m      1 stop   In-flight meal not included  2019
# 2654        07:40  24h 40m      1 stop                       No info  2019
# 2655        21:00   9h 20m      1 stop   In-flight meal not included  2019
# 2656        09:20  12h 10m      1 stop   In-flight meal not included  2019
# 2657        19:15  14h 20m      1 stop                       No info  2019
# 2658        19:00  21h 10m      1 stop   In-flight meal not included  2019
# 2659        12:35    7h 5m     2 stops   In-flight meal not included  2019
# 2660        16:55       5m     2 stops                       No info  2019
# 2661        04:25  33h 15m     2 stops                       No info  2019
# 2662        15:25   1h 30m    non-stop                       No info  2019
# 2663        07:45   8h 15m      1 stop                       No info  2019
# 2664        01:30  10h 15m      1 stop                       No info  2019
# 2665        00:15   1h 30m    non-stop  No check-in baggage included  2019
# 2666        20:25  23h 55m      1 stop                       No info  2019
# 2667        16:55   2h 35m    non-stop                       No info  2019
# 2668        04:25   6h 35m      1 stop                       No info  2019
# 2669        19:15  15h 15m      1 stop                       No info  2019
# 2670        19:15  14h 20m      1 stop                       No info  2019
#
#       Month  Day  Price
# 0         6    6  15998
# 1        12    5  16612
# 2         5   21  25572
# 3         5   21  25778
# 4         6   24  16934
# 5        12    6  21051
# 6        12    3  17813
# 7         1    5  16060
# 8         3   15  16230
# 9         5   18  20533
# 10        3   21  27398
# 11        6   15  17966
# 12        5   15  15953
# 13       12    3  15504
# 14        3    6  25465
# 15        6    3  16611
# 16        6    6  20532
# 17        3   24  26205
# 18       12    6  15145
# 19       12    3  18089
# 20        6    3  25099
# 21        9    5  24547
# 22        3   18  14341
# 23        9    5  17687
# 24        6    4  12863
# 25        3   21  23101
# 26        5   15  19177
# 27        5   21  15961
# 28        6    6  15103
# 29        1    6  18005
# ...     ...  ...    ...
# 2641      9    5  16704
# 2642      5   21  20639
# 2643      6    6  27149
# 2644      3    6  22490
# 2645     12    3  22595
# 2646      5   18  27817
# 2647      1    5  17370
# 2648      1    4  17498
# 2649      6    5  18630
# 2650      9    5  15349
# 2651      6    6  21919
# 2652     12    3  17946
# 2653      5   18  17646
# 2654      3    3  17693
# 2655      6   24  21969
# 2656     12    5  19197
# 2657      6    6  12241
# 2658      6   15  21677
# 2659      6   15  20973
# 2660     12    3  17711
# 2661      3   27  20678
# 2662      5   21  19810
# 2663     12    5  16160
# 2664      6   15  21395
# 2665      6   21  12381
# 2666      6    6  14046
# 2667      3   27  14086
# 2668      6    3  22720
# 2669      6    3  23544
# 2670      6   15  27489
#
# [2671 rows x 13 columns]

# %% [markdown]
# We can now see our target variable in the DataFrame. Hence, we can now Visualize the data.

# %% [markdown]
# # Making DataFrame for the Nominal Data

# %%
#Copying nominal variables into a new dataframe
df_nominal=df[['Airline','Source','Destination','Total_Stops','Additional_Info','Year','Month']].copy()

# %%
#Checking columns of new nominal dataframe created
df_nominal.columns
# Out:
# Index(['Airline', 'Source', 'Destination', 'Total_Stops', 'Additional_Info',
#        'Year', 'Month'],
#       dtype='object')

# %%
#Cheking shape of new nominal dataframe
df_nominal.shape
# Out:
# (2671, 7)

# %% [markdown]
# We have 7 columns in the nominal DataFrame.

# %% [markdown]
# # Visualization of Data

# %% [markdown]
# For the nominal/categorical data we will use countplot as it will gives frequency of the columns.

# %%
#Importing Libraries for Visualization
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Using countplot for nominal data
ab=sns.countplot(x='Airline', data=df_nominal)
print(df_nominal['Airline'].value_counts())
# Out:
# Jet Airways                          897
# IndiGo                               511
# Air India                            440
# Multiple carriers                    347
# SpiceJet                             208
# Vistara                              129
# Air Asia                              86
# GoAir                                 46
# Multiple carriers Premium economy      3
# Jet Airways Business                   2
# Vistara Premium economy                2
# Name: Airline, dtype: int64

# %% [markdown]
# The maximum flights flying are from Jet Airways, Indigo & Air India and least are from Jet Airways Business  & Vistara Premium economy.

# %%
ab=sns.countplot(x='Source', data=df_nominal)
print(df_nominal['Source'].value_counts())
# Out:
# Delhi       1145
# Kolkata      710
# Banglore     555
# Mumbai       186
# Chennai       75
# Name: Source, dtype: int64

# %% [markdown]
# Most of the flights are flying from Delhi and the least are flying from Chennai.

# %%
ab=sns.countplot(x='Destination', data=df_nominal)
print(df_nominal['Destination'].value_counts())
# Out:
# Cochin       1145
# Banglore      710
# Delhi         317
# New Delhi     238
# Hyderabad     186
# Kolkata        75
# Name: Destination, dtype: int64

# %% [markdown]
# Majority of the flights are landing at the Cochin Airport and least are landing at the Kolkata Airport.

# %%
ab=sns.countplot(x='Total_Stops', data=df_nominal)
print(df_nominal['Total_Stops'].value_counts())
# Out:
# 1 stop      1431
# non-stop     849
# 2 stops      379
# 3 stops       11
# 4 stops        1
# Name: Total_Stops, dtype: int64

# %% [markdown]
# The majority flights have only one stop in between the journey and most of them are also non stop but very few flights have 3 & 4 stops.

# %%
ab=sns.countplot(x='Additional_Info', data=df_nominal)
print(df_nominal['Additional_Info'].value_counts())
# Out:
# No info                         2148
# In-flight meal not included      444
# No check-in baggage included      76
# Change airports                    1
# 1 Long layover                     1
# Business class                     1
# Name: Additional_Info, dtype: int64

# %% [markdown]
# As we can see that this column is mostly filled with no information so the column does not serve much importance to our dataset. Hence, we will drop the column.

# %%
#Droping the Additional_Info column from the dataset
af.drop(['Additional_Info'],axis=1,inplace=True)

# %%
ab=sns.countplot(x='Year', data=df_nominal)
print(df_nominal['Year'].value_counts())
# Out:
# 2019    2671
# Name: Year, dtype: int64

# %% [markdown]
# As we see that our whole dataset consists of the year 2019. This data no more serves as any importance to our dataset hence we drop the column.

# %%
#Droping the Year column from the dataset
af.drop(['Year'],axis=1,inplace=True)

# %%
ab=sns.countplot(x='Month', data=df_nominal)
print(df_nominal['Month'].value_counts())
# Out:
# 6     650
# 3     545
# 5     489
# 9     363
# 1     274
# 12    257
# 4      93
# Name: Month, dtype: int64

# %% [markdown]
# Our flights have journey mostly in the month of June, May and March.

# %%
#Verifying dropped column
af.head()
# Out:
#              Airline    Source Destination            Route Dep_Time  \
# 0        Jet Airways     Delhi      Cochin  DEL → BOM → COK    17:30
# 1             IndiGo   Kolkata    Banglore  CCU → MAA → BLR    06:20
# 2        Jet Airways     Delhi      Cochin  DEL → BOM → COK    19:15
# 3  Multiple carriers     Delhi      Cochin  DEL → BOM → COK    08:00
# 4           Air Asia  Banglore       Delhi        BLR → DEL    23:55
#
#   Arrival_Time Duration Total_Stops  Month  Day  Price
# 0        04:25  10h 55m      1 stop      6    6  15998
# 1        10:20       4h      1 stop     12    5  16612
# 2        19:00  23h 45m      1 stop      5   21  25572
# 3        21:00      13h      1 stop      5   21  25778
# 4        02:45   2h 50m    non-stop      6   24  16934

# %% [markdown]
# The columns have been dropped from the above dataset.

# %% [markdown]
# # Making DataFrame of the Ordinal Data

# %%
#Creating ordinal dataframe
df_ordinal=df[['Route']].copy()

# %%
#Verifying columns
df_ordinal.columns
# Out:
# Index(['Route'], dtype='object')

# %%
plt.scatter(af['Route'],af['Price'],alpha=0.5)

# %% [markdown]
# We are not able to understand and predict any conclusion out of the above graph. Hence, we move forward with other visualizations.

# %%
df.dtypes
# Out:
# Airline            object
# Source             object
# Destination        object
# Route              object
# Dep_Time           object
# Arrival_Time       object
# Duration           object
# Total_Stops        object
# Additional_Info    object
# Year                int64
# Month               int64
# Day                 int64
# dtype: object

# %% [markdown]
# We can see that most of our data is string datatype. Hence we will first convert the data using Ordinal Encoder to visualize further.

# %% [markdown]
# # Encoding of DataFrame

# %%
#Importing library for encoding and creating instance for the same 
from sklearn.preprocessing import OrdinalEncoder
enc=OrdinalEncoder()

# %%
#Converting object datatype into float values
for i in af.columns:
    if af[i].dtypes=='object':
        af[i]=enc.fit_transform(af[i].values.reshape(-1,1))

# %%
#Verifying Conversion 
af.head()
# Out:
#    Airline  Source  Destination  Route  Dep_Time  Arrival_Time  Duration  \
# 0      4.0     2.0          1.0   76.0     138.0          25.0      10.0
# 1      3.0     3.0          0.0   65.0      31.0          67.0     248.0
# 2      4.0     2.0          1.0   76.0     156.0         154.0     148.0
# 3      6.0     2.0          1.0   76.0      48.0         172.0      36.0
# 4      0.0     0.0          2.0   16.0     198.0          17.0     216.0
#
#    Total_Stops  Month  Day  Price
# 0          0.0      6    6  15998
# 1          0.0     12    5  16612
# 2          0.0      5   21  25572
# 3          0.0      5   21  25778
# 4          4.0      6   24  16934

# %% [markdown]
# We can see that our data has been encoded and has been converted to float values.

# %% [markdown]
# # Making DataFrame of the Continuous type of Values

# %%
#Copying our continuous data into a new dataframe
df_continuous=af[['Dep_Time', 'Arrival_Time','Duration','Price','Day']].copy()

# %%
#Verifying columns
df_continuous.columns
# Out:
# Index(['Dep_Time', 'Arrival_Time', 'Duration', 'Price', 'Day'], dtype='object')

# %% [markdown]
# # Visualizing Continuous Data

# %%
#Visualizing different columns using distplot
ncol,nrow=9,3
ab=df_continuous.columns.values
plt.figure(figsize=(20,20))
for index,i in enumerate(ab):
    ab=plt.subplot(ncol,nrow,index+1)
    sns.distplot(af[i])
    plt.title(f"plot {i}")
    plt.tight_layout()
plt.show()

# %% [markdown]
# Observations:
#
# We can see that the data is broadly scattered in all columns except for the price column.
#
# The data in price column is right skewed but it is a target variable so we don't consider the skewness of this column.
#
# The data in Dep_Time & Arrival_Time column is scattered between the range 0 and 200.
#
# The data in duration column lies is in between the range 0 and 325.
#
# In Day column, we can see that the maximum number of flights are flying between the dates 3 and 7.

# %%
#using multivariate analysis

sns.pairplot(af)

# %% [markdown]
# As most of the data in our dataset is of the object datatype so we are unable to understand the data using this analysis. Hence, we'll try using other visualization techniques to understand the data.

# %% [markdown]
# # Describe Data

# %%
#Describing final columns present in dataset
af.columns
# Out:
# Index(['Airline', 'Source', 'Destination', 'Route', 'Dep_Time', 'Arrival_Time',
#        'Duration', 'Total_Stops', 'Month', 'Day', 'Price'],
#       dtype='object')

# %%
#Defining Shape
af.shape
# Out:
# (2671, 11)

# %% [markdown]
# We finally now have 11 columns inour dataset.

# %%
#Getting data information
af.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2671 entries, 0 to 2670
# Data columns (total 11 columns):
# Airline         2671 non-null float64
# Source          2671 non-null float64
# Destination     2671 non-null float64
# Route           2671 non-null float64
# Dep_Time        2671 non-null float64
# Arrival_Time    2671 non-null float64
# Duration        2671 non-null float64
# Total_Stops     2671 non-null float64
# Month           2671 non-null int64
# Day             2671 non-null int64
# Price           2671 non-null int64
# dtypes: float64(8), int64(3)
# memory usage: 229.6 KB

# %% [markdown]
# There are 10683 rows and no null values in our data. Also the values in the dataset are in the form of float and int. Now, we can try understanding our data better.

# %%
#Visualizing data description
import matplotlib.pyplot as plt
plt.figure(figsize=(22,7))
sns.heatmap(af.describe(),annot=True,linewidths=0.1,linecolor='blue',fmt='0.2f')

# %% [markdown]
# Observation:
#
# The standard deviation in the Route, Dep_Time, Arrival_time, Duration and Price column is too high which means that the values in these columns are largely scattered.
#
# The standard devation of other columns is not too high which shows us a normal distribution of data and no skewness.
#
# The values of Price column which is the target variable starts from 10,138 and ends at a rate 64,881. The range is too high.

# %% [markdown]
# # Correlation of Columns with the Target Variable

# %%
#Plotting correlation of input features with the target Variable
plt.figure(figsize=(22,7))
sns.heatmap(af.corr(),annot=True,linewidths=0.1,linecolor='black',fmt='0.2f')

# %% [markdown]
# Observations:
#
# We dont see any high positive correlation in our data with respect to the target variable.
#
# The most negatively correlated column is that of the Total_Stops which means more the number of stops less the flight price.
#
# The most positively correlated column is the Source & Arrival_Time and the most negatively correlated is the TOtal_Stops.

# %%
#Plotting Correlation in order with the target variable
plt.figure(figsize=(22,7))
af.corr()['Price'].sort_values(ascending=False).drop(['Price']).plot(kind='bar',color='c')
plt.xlabel('Feature',fontsize=14)
plt.ylabel('column with target names',fontsize=14)
plt.title('correlation',fontsize=18)
plt.show()

# %% [markdown]
# The columns Route, Arrival_Time, Source, Month and Dep_Time are positively correlated with the Target Variable and columns Airline, Destination, Duration, Day and Total_STops are negatively correlated.

# %%
af.shape
# Out:
# (2671, 11)

# %% [markdown]
# # Checking Skewness

# %%
#checking skewness
df.skew()
# Out:
# Year     0.000000
# Month    0.590701
# Day      0.478246
# dtype: float64

# %% [markdown]
# Keeping threshold +/-0.5 as the range for skewness, we do not see much skewness in our data. Only columns Destination, Total_Stops and Month show skewness wherein all the input features are of the Object datatype and Price is the Target Variable. Hence, there is no skewness found in our data.

# %% [markdown]
# # Checking Outliers

# %%
#Visualizing outliers of different variables
collist=af.columns.values
ncol=12
nrows=10
plt.figure(figsize=(ncol,5*ncol))
for i in range(1,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(af[collist[i]],color='green',orient='v')
    plt.tight_layout()

# %% [markdown]
# We can observe outliers only in the Price column which is the Target Variable, hence we dont consider the outlier present in our data.

# %% [markdown]
# # Separating the columns into x & y

# %%
#Creating x & y columns 
x=af.drop('Price',axis=1)
y=af['Price']

# %% [markdown]
# Separating the columns into x & y as input featues and target variable respectively.

# %% [markdown]
# # Scaling Data Using Standard Scaler

# %%
#importing library for scaling
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings('ignore')

# %%
#Scaling our data to improve model performance
sc=StandardScaler()
x=sc.fit_transform(af)
x
# Out:
# array([[ 0.01190758,  0.03256662, -0.29488167, ...,  0.12908857,
#         -0.70385305, -0.83156077],
#        [-0.42377921,  0.87708559, -0.97622158, ...,  2.10122721,
#         -0.82063721, -0.70887027],
#        [ 0.01190758,  0.03256662, -0.29488167, ..., -0.1996012 ,
#          1.04790943,  1.08153193],
#        ...,
#        [ 0.01190758,  0.03256662, -0.29488167, ...,  0.12908857,
#         -1.05420554,  0.51164051],
#        [-1.29515278,  0.03256662, -0.29488167, ...,  0.12908857,
#         -1.05420554,  0.67629357],
#        [ 0.88328115,  0.03256662, -0.29488167, ...,  0.12908857,
#          0.34720444,  1.46459007]])

# %% [markdown]
# Hence, the data is Scaled.

# %% [markdown]
# # Loading the Best Saved Model

# %%
#Loading model
import pickle
fitted_model=pickle.load(open('Flight.pkl','rb'))

# %%
fitted_model
# Out:
# AdaBoostRegressor(base_estimator=None, learning_rate=1.0, loss='linear',
#          n_estimators=100, random_state=0)

# %% [markdown]
# # Predicting The Test File using the Pre Saved Model

# %%
#Prediction over test data
predictions=fitted_model.predict(af)

# %%
predictions
# Out:
# array([34514.83875   , 55779.2       , 33873.52666667, ...,
#        34514.83875   , 34514.83875   , 34514.83875   ])

# %% [markdown]
# # Conclusion:

# %%
fitted_model=pickle.load(open('Flight.pkl','rb'))
result=fitted_model.score(x_test,y_test)
print(result)
# Out:
# 0.9821093210657594

# %%
conclusion=pd.DataFrame([fitted_model.predict(x_test)[:],pred_y[:]],index=["Predicted","Original"])

# %%
conclusion
# Out:
#                   0            1             2             3             4     \
# Predicted  3565.672582  6734.203377  14129.410032  14129.410032  10983.529514
# Original   3565.672582  6734.203377  14129.410032  14129.410032  10983.529514
#
#                    5            6             7           8           9     \
# Predicted  14335.222343  5151.293794  10827.216953  7708.62706  4376.68073
# Original   14335.222343  5151.293794  10827.216953  7708.62706  4376.68073
#
#            ...         2127         2128          2129         2130  \
# Predicted  ...  16307.46846  6912.454461  11043.699697  7647.255739
# Original   ...  16307.46846  6912.454461  11043.699697  7647.255739
#
#                   2131         2132         2133          2134         2135  \
# Predicted  8485.887663  9158.075574  3565.672582  14335.222343  6912.454461
# Original   8485.887663  9158.075574  3565.672582  14335.222343  6912.454461
#
#                  2136
# Predicted  4376.68073
# Original   4376.68073
#
# [2 rows x 2137 columns]

# %% [markdown]
# Hence, we can observe that our original and predicted outputs are matching which means that we have attained the best accuracy possible for our model.
