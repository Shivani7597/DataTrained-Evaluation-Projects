# %% [markdown]
# # Problem Description:

# %% [markdown]
# The task is to train a model to predict the number of wins for a given team in the 2015 season based on 16 different features that will be used as the inputs and the output will be number of wins.

# %% [markdown]
# Input features: Runs, At Bats, Hits, Doubles, Triples, Homeruns, Walks, Strikeouts, Stolen Bases, Runs Allowed, Earned Runs, Earned Run Average (ERA), Complete Game, Shutouts, Saves, and Errors

# %% [markdown]
# # Importing the Dataset

# %%
#Importing Libraries
import pandas as pd
import numpy as np

# %%
#Importing Dataset
df=pd.read_csv('baseball.csv')
#Visualizing first 5 rows of dataset
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %% [markdown]
# In the above Dataframe, we can see there are 16 input columns and an output column 'W'

# %% [markdown]
# # Checking Null Values in the DataFrame

# %%
#Checking Null values
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
#Using heatmap to check Null Values
import seaborn as sns
sns.heatmap(df.isnull())

# %% [markdown]
# Hence, we cannot find any null values in the above Dataset

# %% [markdown]
# # Visualization of Data

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Univariate Analysis
plt.hist(df['E'],bins=10)
# Out:
# (array([5., 1., 9., 6., 2., 1., 0., 1., 3., 2.]),
#  array([ 75. ,  80.1,  85.2,  90.3,  95.4, 100.5, 105.6, 110.7, 115.8,
#         120.9, 126. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# The Errors are more between values 85 to 90

# %%
#Univariate Analysis
df['SHO'].plot.bar()

# %% [markdown]
# The maximum number of shutouts are at values 17 & 25

# %%
#Univariate Analysis
sns.violinplot(x='AB',data=df)

# %% [markdown]
# The maximum data in column At Bats are between values 5450 and 5550

# %%
#Univariate Analysis
sns.distplot(df['RA'],bins=20)

# %% [markdown]
# The maximum number of Runs Allowed lies between the range 590 to 770 and the data is normally distributed.

# %%
#Bivariate Analysis
plt.scatter(df["E"],df["W"],alpha=0.5)
plt.title("E vs W")
plt.show()

# %% [markdown]
# As the number of Errors increased, the number of Wins decreased. Hence they are negatively correlated to each other.

# %%
#Bivariate Analysis
plt.scatter(df["3B"],df["W"],alpha=0.5)
plt.title("ERA vs W")
plt.show()

# %% [markdown]
# The data is fully scattered and we cannot observe any proper correlation between the columns. Let's try using pairplot for better understanding.

# %%
sns.pairplot(df)

# %% [markdown]
# Variables RA, ER, 3B and ERA are in negative linear correlation to the Wins. Variables SV, SHO, BB, HR and R are in positive correlation to the Wins. This is the observation from the above graph. For better understanding of correlated variables, Let's understand data and use heatmap to see correlations.

# %% [markdown]
# # Describe Data

# %%
df.shape
# Out:
# (30, 17)

# %% [markdown]
# There are 30 rows and 17 columns in the Dataset.

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %% [markdown]
# These are the different variables present in our dataset.

# %%
#getting information of our data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
# W      30 non-null int64
# R      30 non-null int64
# AB     30 non-null int64
# H      30 non-null int64
# 2B     30 non-null int64
# 3B     30 non-null int64
# HR     30 non-null int64
# BB     30 non-null int64
# SO     30 non-null int64
# SB     30 non-null int64
# RA     30 non-null int64
# ER     30 non-null int64
# ERA    30 non-null float64
# CG     30 non-null int64
# SHO    30 non-null int64
# SV     30 non-null int64
# E      30 non-null int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# All our variables have integer datatype but the ERA variable has float datatype.

# %%
#Describing our data
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# min    13.000000  100.000000  375.000000   973.00000   44.000000  525.000000
# 25%    23.000000  140.250000  428.250000  1157.50000   69.000000  636.250000
# 50%    31.000000  158.500000  473.000000  1261.50000   83.500000  695.500000
# 75%    39.000000  177.000000  501.250000  1311.50000   96.500000  732.500000
# max    49.000000  232.000000  570.000000  1518.00000  134.000000  844.000000
#
#                ER        ERA         CG        SHO         SV           E
# count   30.000000  30.000000  30.000000  30.000000  30.000000   30.000000
# mean   635.833333   3.956333   3.466667  11.300000  43.066667   94.333333
# std     70.140786   0.454089   2.763473   4.120177   7.869335   13.958889
# min    478.000000   2.940000   0.000000   4.000000  28.000000   75.000000
# 25%    587.250000   3.682500   1.000000   9.000000  37.250000   86.000000
# 50%    644.500000   4.025000   3.000000  12.000000  42.000000   91.000000
# 75%    679.250000   4.220000   5.750000  13.000000  46.750000   96.750000
# max    799.000000   5.040000  11.000000  21.000000  62.000000  126.000000

# %%
#Describing data using heatmap
import matplotlib.pyplot as plt
plt.figure(figsize=(22,7))
sns.heatmap(df.describe(),annot=True,linewidths=0.1,linecolor='blue',fmt='0.2f')

# %% [markdown]
# From the above description we can see that data of most of the columns are broadly scattered i.e. the std of most columns are quite high.
#
# There are no huge variations in the min and max values of each column which means that it has a less chance of having outliers.
#
# Every column has a differnt range of values which shows huge variations in the values of a dataset.

# %% [markdown]
# # Correlation of Columns with the Target Variable

# %%
#Finding correlation between variables
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ERA -0.819600 -0.049281  0.255551  0.231172 -0.254854  0.330951 -0.090917
# CG   0.080533  0.232042 -0.080876  0.147955  0.306675 -0.065898  0.156502
# SHO  0.471805 -0.103274 -0.197321 -0.145559  0.057998 -0.041396 -0.019119
# SV   0.666530 -0.096380 -0.106367 -0.130371  0.171576 -0.142370 -0.028540
# E   -0.089485 -0.023262  0.316743 -0.033173  0.105754  0.126678 -0.207597
#
#            BB        SO        SB        RA        ER       ERA        CG  \
# W    0.484342  0.111850 -0.157234 -0.812952 -0.809435 -0.819600  0.080533
# R    0.402452 -0.054726  0.081367 -0.041623 -0.041245 -0.049281  0.232042
# AB  -0.136414 -0.106022  0.372618  0.316010  0.309686  0.255551 -0.080876
# H   -0.118281 -0.398830  0.413444  0.224324  0.252489  0.231172  0.147955
# 2B   0.302700 -0.150752  0.195027 -0.218160 -0.235531 -0.254854  0.306675
# 3B  -0.454949 -0.141196  0.457437  0.314125  0.340225  0.330951 -0.065898
# HR   0.425691  0.359923 -0.136567 -0.103903 -0.085922 -0.090917  0.156502
# BB   1.000000  0.233652 -0.098347 -0.416445 -0.452663 -0.459832  0.462478
# SO   0.233652  1.000000  0.030968 -0.129745 -0.161612 -0.180368 -0.093418
# SB  -0.098347  0.030968  1.000000  0.132290  0.143068  0.126063 -0.020783
# RA  -0.416445 -0.129745  0.132290  1.000000  0.991018  0.986674 -0.016659
# ER  -0.452663 -0.161612  0.143068  0.991018  1.000000  0.997248 -0.020221
# ERA -0.459832 -0.180368  0.126063  0.986674  0.997248  1.000000 -0.009856
# CG   0.462478 -0.093418 -0.020783 -0.016659 -0.020221 -0.009856  1.000000
# SHO  0.426004  0.237721 -0.106563 -0.636862 -0.630192 -0.630833  0.241676
# SV   0.099445  0.126297 -0.183418 -0.616224 -0.589663 -0.607005 -0.367766
# E   -0.075685  0.155133  0.079149  0.198996  0.136921  0.113137 -0.140047
#
#           SHO        SV         E
# W    0.471805  0.666530 -0.089485
# R   -0.103274 -0.096380 -0.023262
# AB  -0.197321 -0.106367  0.316743
# H   -0.145559 -0.130371 -0.033173
# 2B   0.057998  0.171576  0.105754
# 3B  -0.041396 -0.142370  0.126678
# HR  -0.019119 -0.028540 -0.207597
# BB   0.426004  0.099445 -0.075685
# SO   0.237721  0.126297  0.155133
# SB  -0.106563 -0.183418  0.079149
# RA  -0.636862 -0.616224  0.198996
# ER  -0.630192 -0.589663  0.136921
# ERA -0.630833 -0.607005  0.113137
# CG   0.241676 -0.367766 -0.140047
# SHO  1.000000  0.221639 -0.115716
# SV   0.221639  1.000000 -0.025636
# E   -0.115716 -0.025636  1.000000

# %% [markdown]
# We can see both Postive and Negative correlation between variables in the dataset.

# %%
#Using heatmap to see Correlation
plt.figure(figsize=(22,7))
sns.heatmap(df.corr(),annot=True,linewidths=0.1,linecolor='black',fmt='0.2f')
plt.show()

# %% [markdown]
# Observations -
#
# The most positively correlated columns to the number of Wins are Saves(SV), Shutouts(SHO), Walks(BB), Runs(R) and Doubles(2B)
#
# The most negatively correlated columns to the number of WIns are Runs Allowed(RA),Earned Runs(ER)and Earned Run Average(ERA)

# %%
#Sorting correlation of input variables with the Target variable 
plt.figure(figsize=(22,7))
df.corr()['W'].sort_values(ascending=False).drop(['W']).plot(kind='bar',color='c')
plt.xlabel('Feature',fontsize=14)
plt.ylabel('column with target names',fontsize=14)
plt.title('correlation',fontsize=18)
plt.show()

# %% [markdown]
# Observation -
#
# Variables SV, BB, SHO, R, 2B, HR, SO, CG & H  are positively correlated with the Target Variable i.e. Number of Wins(W)
#
# Variables AB, E, SB, 3B, ER, RA & ERA are negatively correlated with the Target Variable i.e. Number of Wins(W)

# %% [markdown]
# # Checking Skewness

# %%
#Checking Skewness 
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# Keeping threshold +/-0.5 as the range for skewness, we can see that there is not much skewness in our data. Hardly some skewness can be seen in columns H, R, CG, SH0, SV & E. Let's try plotting skewness in columns using density graph.

# %%
#Visualizing skewness on density graph
#Example of multi variate analysis
df.plot(kind='density',subplots=True,layout=(4,10),legend=False,sharex=False,figsize=(30,20))
plt.show()

# %% [markdown]
# We can observe that most of our data is normally distributed. Hardly, any skewness can be seen.

# %% [markdown]
# # Checking Outliers

# %%
#Checking datatype of data in each column 
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# All our variables have integer datatype but the ERA variable has float datatype.

# %%
df['R'].plot.box()

# %% [markdown]
# Ony one outlier value can be found

# %%
df['E'].plot.box()

# %% [markdown]
# Only few outliers can be detected

# %%
df['CG'].plot.box()

# %% [markdown]
# No outlier can be detected

# %%
#Multivariate analysis to check outliers
df.plot(kind='box',subplots=True,layout=(4,8),figsize=(10,20))
# Out:
# W          AxesSubplot(0.125,0.71587;0.0824468x0.16413)
# R       AxesSubplot(0.223936,0.71587;0.0824468x0.16413)
# AB      AxesSubplot(0.322872,0.71587;0.0824468x0.16413)
# H       AxesSubplot(0.421809,0.71587;0.0824468x0.16413)
# 2B      AxesSubplot(0.520745,0.71587;0.0824468x0.16413)
# 3B      AxesSubplot(0.619681,0.71587;0.0824468x0.16413)
# HR      AxesSubplot(0.718617,0.71587;0.0824468x0.16413)
# BB      AxesSubplot(0.817553,0.71587;0.0824468x0.16413)
# SO        AxesSubplot(0.125,0.518913;0.0824468x0.16413)
# SB     AxesSubplot(0.223936,0.518913;0.0824468x0.16413)
# RA     AxesSubplot(0.322872,0.518913;0.0824468x0.16413)
# ER     AxesSubplot(0.421809,0.518913;0.0824468x0.16413)
# ERA    AxesSubplot(0.520745,0.518913;0.0824468x0.16413)
# CG     AxesSubplot(0.619681,0.518913;0.0824468x0.16413)
# SHO    AxesSubplot(0.718617,0.518913;0.0824468x0.16413)
# SV     AxesSubplot(0.817553,0.518913;0.0824468x0.16413)
# E         AxesSubplot(0.125,0.321957;0.0824468x0.16413)
# dtype: object

# %% [markdown]
# There are very minimal number of outliers present which can be of huge importance to our data. Hence, we don't resolve them.

# %% [markdown]
# # Separating the column into x & y

# %%
x=df.drop('W',axis=1)
y=df['W']

# %% [markdown]
# Dropping column W from our x data and adding it to our y data.

# %% [markdown]
# # Scaling data using Standard Scaler

# %%
#importing library for scaling
from sklearn.preprocessing import StandardScaler

# %%
#Scaling our data to improve model performance
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[ 0.61907797,  0.84773126,  1.66368512,  1.42017307,  1.04119304,
#         -0.7872986 , -1.53490242, -2.69762957,  0.91388329, -0.66623393,
#         -0.50511008, -0.50695519, -0.5398062 , -0.81462859,  1.67160651,
#         -0.46146963],
#        [ 0.13443166, -0.71109353, -0.97068076,  0.12740339,  1.23580856,
#         -0.24396668, -0.5365919 ,  0.15487844, -0.60182558,  0.16597077,
#          0.24892985,  0.25459752, -0.5398062 ,  0.1728    ,  0.24987932,
#         -0.60719689],
#        [-0.33290586, -1.1152333 , -0.15189137,  1.58879521, -0.22380785,
#         -0.7233772 ,  1.13914361, -0.89398189,  0.11144918, -0.68033909,
#         -0.75162313, -0.64134684,  2.77264091, -0.32091429, -0.65485616,
#         -1.11724227],
#        [-1.14641931,  0.24152162, -0.40108814, -0.82812203, -0.41842337,
#         -0.8831807 , -1.16053598, -0.16860185, -0.69098493,  0.18007593,
#          0.10392217,  0.05301004,  1.3004422 , -0.56777144, -0.78410408,
#          0.48575751],
#        [ 0.01327008,  1.28073815,  1.98408098,  0.80189192,  1.72234737,
#         -0.40377019, -0.25136033,  0.10586628, -0.02228984,  1.61880269,
#          1.59750126,  1.53131824,  1.3004422 ,  0.1728    , -1.04259994,
#         -0.60719689],
#        [ 3.50964704, -0.10488389,  1.36108904,  1.86983209, -1.39150098,
#          2.18504658,  1.79874163, -0.95279649,  0.20060853, -0.25718416,
#         -0.38910394, -0.35016492,  1.3004422 , -0.32091429, -1.17184786,
#         -0.46146963],
#        [ 1.31142984,  0.73226276, -0.11629183, -0.1536335 , -1.19688546,
#          1.54583256,  1.51351006, -0.20781158, -0.91388329,  0.13776044,
#          0.23442908,  0.16500309, -0.17175652, -1.80205719,  0.6376231 ,
#         -0.0971515 ],
#        [ 0.4286812 , -0.4512894 , -0.5968856 , -1.61502532, -1.0995777 ,
#          1.70563607, -0.91095835,  0.81164146, -1.76089707,  0.06723462,
#          0.14742447,  0.20980031, -1.27590555, -0.32091429, -0.00861653,
#         -1.26296953],
#        [-0.76562578, -0.4512894 , -0.3654886 ,  0.18361077,  0.06811543,
#          0.10760103, -0.59007283,  0.60579036,  0.15602885, -0.65212876,
#         -0.46160778, -0.48455658, -0.90785587,  0.1728    ,  2.18859821,
#          0.04857575],
#        [ 1.03448909,  1.78591286,  1.62808558,  1.08292881,  0.16542319,
#         -0.08416318,  0.15866006, -0.98220379, -0.55724591,  0.91354447,
#          0.84346133,  0.79216414, -0.17175652, -0.32091429, -0.39636031,
#          0.194303  ],
#        [ 1.08641548, -0.07601676,  0.2753031 ,  0.23981814,  0.06811543,
#          0.26740453,  0.6043344 , -0.14899698,  0.78014427,  0.63144119,
#          0.64045058,  0.63537388,  0.56434284, -0.56777144,  0.24987932,
#          1.79730279],
#        [ 0.70562195, -0.82656204, -0.72148399,  0.18361077, -0.51573113,
#          2.12112518,  0.30127585,  1.40958987,  1.67173773, -0.99065271,
#         -0.92563235, -0.86533293,  0.56434284,  0.41965715, -0.52560823,
#         -0.68006051],
#        [-0.47137623, -1.43277168, -1.29107662, -1.78364745, -1.00226994,
#          0.39524733, -0.6078998 , -0.96259892, -1.40425969, -0.18665834,
#         -0.08458781, -0.03658439, -0.5398062 ,  0.1728    ,  0.37912725,
#         -0.0971515 ],
#        [-0.55792022,  0.40029081, -0.43668768, -0.71570727, -0.90496218,
#          1.09838275,  0.15866006,  0.86065362, -0.64640525,  0.53270504,
#          0.59694828,  0.45618501,  0.93239252,  0.1728    ,  0.24987932,
#         -0.02428788],
#        [ 0.09981406,  1.20857034,  0.02610633,  0.12740339,  1.43042408,
#         -0.56357369,  0.10517914, -1.26647435, -0.2451882 ,  0.57502053,
#          0.40843829,  0.41138779,  0.56434284,  0.91337145, -1.94733542,
#          2.30734817],
#        [-0.71369939, -0.46572296, -0.31208929,  0.74568454,  0.74926976,
#         -0.85122   ,  0.65781532,  0.18428574, -0.64640525, -2.30243298,
#         -2.28870452, -2.2764453 , -0.90785587,  0.91337145,  2.44709406,
#          0.12143938],
#        [ 0.15174045,  1.65601079,  1.04069319,  0.97051405, -0.41842337,
#         -0.7553379 , -0.14439849,  0.72341956,  0.64640525, -1.30096632,
#         -1.50566306, -1.67168286, -1.27590555,  0.41965715,  1.41311066,
#          2.01589367],
#        [ 0.01327008, -0.36468802, -1.11307892, -0.1536335 , -0.12650009,
#          0.23544383,  1.74526071,  2.64469643,  0.51266624, -1.13170435,
#         -1.30265231, -1.33570372,  0.93239252,  2.39451435,  0.6376231 ,
#          1.21439378],
#        [-0.57522902, -0.52345722, -0.45448745, -0.04121874,  0.26273095,
#         -0.59553439, -1.01792019,  0.4979636 ,  0.02228984,  0.68786185,
#          0.66945211,  0.72496831, -0.90785587, -1.06148574, -0.39636031,
#          1.57871191],
#        [-0.83486097,  0.78999701, -0.38328837, -0.99674416, -0.41842337,
#          0.10760103,  0.47954559,  0.06665654,  2.25127347,  0.92764964,
#          0.93046594,  0.83696136, -0.5398062 , -0.81462859, -1.04259994,
#         -0.31574238],
#        [-0.0905827 ,  0.15492024, -0.93508123,  1.13913619, -1.39150098,
#          0.42720803,  0.3369298 ,  0.4097417 , -1.44883936, -1.06117853,
#         -1.14314386, -1.17891346, -0.90785587,  0.6665143 ,  0.89611895,
#         -0.46146963],
#        [ 0.25559323, -1.27400249, -0.72148399, -0.54708514, -1.78073202,
#          0.42720803,  1.24610545,  0.93907309, -1.18136133, -0.75086491,
#         -0.85312851, -0.75333989,  0.19629316,  0.41965715, -0.26711238,
#         -0.31574238],
#        [-1.30219848, -0.76882779,  0.29310287, -2.17709909,  0.84657752,
#         -1.39455191, -1.67751821, -0.96259892,  1.27052067, -0.14434285,
#          0.03141833,  0.14260448, -1.27590555,  0.1728    , -1.04259994,
#         -1.26296953],
#        [-1.99455036, -1.38947099, -0.75708353, -1.33398843, -1.29419322,
#         -2.03376593,  0.03387125, -1.38410355, -0.64640525,  1.01228062,
#          0.9014644 ,  1.01615023, -0.17175652, -0.32091429,  0.1206314 ,
#         -0.31574238],
#        [-1.07718413,  0.18378737, -0.52568653, -0.1536335 ,  0.55465424,
#         -1.07494491, -1.46359453,  0.25290277,  0.20060853,  1.70343367,
#          1.64100356,  1.64331129, -0.90785587, -1.06148574, -1.04259994,
#          1.65157553],
#        [-0.36752345, -1.8946457 , -1.02408007, -0.6594999 , -0.51573113,
#          0.74681504,  1.67395282,  0.09606384, -1.09220198, -1.31507148,
#         -1.20114693, -1.15651485,  0.93239252,  2.39451435,  0.50837518,
#         -1.40869678],
#        [ 0.13443166,  0.70339563,  1.46788766,  0.74568454,  0.74926976,
#         -0.8831807 , -0.21570638, -0.87437703,  0.42350689, -0.86370623,
#         -0.56311315, -0.52935379,  1.3004422 ,  1.6539429 , -0.26711238,
#         -1.1901059 ],
#        [ 0.54984278,  1.91581492,  1.61028582,  0.80189192,  1.6250396 ,
#         -0.30788808,  0.37258375,  0.62539523,  2.16211413,  0.3493379 ,
#          0.33593445,  0.1874017 , -0.90785587,  0.1728    ,  0.1206314 ,
#         -0.60719689],
#        [-0.661773  , -0.85542916, -1.415675  , -0.82812203,  0.45734648,
#         -0.49965229, -0.76834256,  0.77243172, -0.06686951,  0.60323086,
#          0.27793138,  0.29939474, -0.90785587, -1.30834289, -0.26711238,
#         -0.17001513],
#        [ 0.84409233,  0.80443057,  1.34328927, -0.04121874,  1.72234737,
#          0.71485434, -1.44576756,  0.34112467,  0.60182558,  2.19711442,
#          2.36604195,  2.42726261,  0.19629316, -1.80205719, -0.91335201,
#          0.04857575]])

# %% [markdown]
# Our int data automatically gets converted into float datatype when we use Standard Scaling.

# %% [markdown]
# # Model Building

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

# %%
lr=LinearRegression()
for i in range(0,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    print(f'At random state {i}, the training accuracy is: {r2_score(y_train,pred_train)}')
    print(f'At random state {i}, the testing accuracy is: {r2_score(y_test,pred_test)}')
    print("\n")
# Out:
# At random state 0, the training accuracy is: 0.9609590618835543
# At random state 0, the testing accuracy is: 0.6629341689506446
#
#
# At random state 1, the training accuracy is: 0.9715846357165404
# At random state 1, the testing accuracy is: 0.38417246900757474
#
#
# At random state 2, the training accuracy is: 0.9898192153844542
# At random state 2, the testing accuracy is: -2.0819989550103877
#
#
# At random state 3, the training accuracy is: 0.9722553885185528
# At random state 3, the testing accuracy is: 0.46183789706024414
#
#
# At random state 4, the training accuracy is: 0.9647461497996579
# At random state 4, the testing accuracy is: 0.46606852927277453
#
#
# At random state 5, the training accuracy is: 0.950309288736999
# At random state 5, the testing accuracy is: 0.7517105066858121
#
#
# At random state 6, the training accuracy is: 0.9489470045214469
# At random state 6, the testing accuracy is: 0.8376419521868405
#
#
# At random state 7, the training accuracy is: 0.9631978535911321
# At random state 7, the testing accuracy is: -0.25547694158882717
#
#
# At random state 8, the training accuracy is: 0.9623956064118223
# At random state 8, the testing accuracy is: 0.586867650000877
#
#
# At random state 9, the training accuracy is: 0.9558190206474733
# At random state 9, the testing accuracy is: 0.7290448155516256
#
#
# At random state 10, the training accuracy is: 0.965838048823881
# At random state 10, the testing accuracy is: -0.22797129199498234
#
#
# At random state 11, the training accuracy is: 0.9794801537272682
# At random state 11, the testing accuracy is: 0.24817597656146917
#
#
# At random state 12, the training accuracy is: 0.9737413001008607
# At random state 12, the testing accuracy is: -1.191655006420163
#
#
# At random state 13, the training accuracy is: 0.9750450815078384
# At random state 13, the testing accuracy is: 0.6767079843344621
#
#
# At random state 14, the training accuracy is: 0.9469984720280225
# At random state 14, the testing accuracy is: 0.7947948235207252
#
#
# At random state 15, the training accuracy is: 0.970942094140768
# At random state 15, the testing accuracy is: 0.08782646885310441
#
#
# At random state 16, the training accuracy is: 0.9858809375178786
# At random state 16, the testing accuracy is: 0.21566361427485714
#
#
# At random state 17, the training accuracy is: 0.9749884441968529
# At random state 17, the testing accuracy is: 0.2429837566512596
#
#
# At random state 18, the training accuracy is: 0.961905153879102
# At random state 18, the testing accuracy is: 0.44692713019863173
#
#
# At random state 19, the training accuracy is: 0.9495167250254275
# At random state 19, the testing accuracy is: 0.8381134193356252
#
#
# At random state 20, the training accuracy is: 0.9648282100620998
# At random state 20, the testing accuracy is: 0.3010355318344323
#
#
# At random state 21, the training accuracy is: 0.9632922835126105
# At random state 21, the testing accuracy is: 0.43748497306627954
#
#
# At random state 22, the training accuracy is: 0.9538756336575566
# At random state 22, the testing accuracy is: -0.022968263180366266
#
#
# At random state 23, the training accuracy is: 0.9614513761755266
# At random state 23, the testing accuracy is: 0.5703263346962941
#
#
# At random state 24, the training accuracy is: 0.9930550857101428
# At random state 24, the testing accuracy is: -3.928138688717561
#
#
# At random state 25, the training accuracy is: 0.9579610563737944
# At random state 25, the testing accuracy is: 0.4181713062412772
#
#
# At random state 26, the training accuracy is: 0.9658277445021989
# At random state 26, the testing accuracy is: 0.3241336086511961
#
#
# At random state 27, the training accuracy is: 0.9552740421332099
# At random state 27, the testing accuracy is: 0.6767959850140888
#
#
# At random state 28, the training accuracy is: 0.9597644213445622
# At random state 28, the testing accuracy is: 0.6699377101719027
#
#
# At random state 29, the training accuracy is: 0.9511213168423279
# At random state 29, the testing accuracy is: 0.879050722953303
#
#
# At random state 30, the training accuracy is: 0.9494811939208995
# At random state 30, the testing accuracy is: 0.8365092739163201
#
#
# At random state 31, the training accuracy is: 0.9951572148896561
# At random state 31, the testing accuracy is: 0.25920838276351077
#
#
# At random state 32, the training accuracy is: 0.9631618129568901
# At random state 32, the testing accuracy is: 0.24486497945423824
#
#
# At random state 33, the training accuracy is: 0.9828979279570369
# At random state 33, the testing accuracy is: 0.725164423752706
#
#
# At random state 34, the training accuracy is: 0.9721607076503063
# At random state 34, the testing accuracy is: 0.7974272428667495
#
#
# At random state 35, the training accuracy is: 0.9800685115224866
# At random state 35, the testing accuracy is: 0.18097976995387977
#
#
# At random state 36, the training accuracy is: 0.9577869158330775
# At random state 36, the testing accuracy is: 0.7342034319837668
#
#
# At random state 37, the training accuracy is: 0.9564708376178137
# At random state 37, the testing accuracy is: 0.5924138149123747
#
#
# At random state 38, the training accuracy is: 0.9684911861559722
# At random state 38, the testing accuracy is: 0.23284767333797662
#
#
# At random state 39, the training accuracy is: 0.9531716157253376
# At random state 39, the testing accuracy is: 0.8073613092401313
#
#
# At random state 40, the training accuracy is: 0.9693187478384307
# At random state 40, the testing accuracy is: 0.45805077232054847
#
#
# At random state 41, the training accuracy is: 0.958621898229464
# At random state 41, the testing accuracy is: 0.73436960652363
#
#
# At random state 42, the training accuracy is: 0.974042638444853
# At random state 42, the testing accuracy is: 0.7876400316149385
#
#
# At random state 43, the training accuracy is: 0.9881881791911085
# At random state 43, the testing accuracy is: -1.054342889660337
#
#
# At random state 44, the training accuracy is: 0.9567296904413441
# At random state 44, the testing accuracy is: 0.5894992447123877
#
#
# At random state 45, the training accuracy is: 0.9549549017905322
# At random state 45, the testing accuracy is: 0.6385651240924837
#
#
# At random state 46, the training accuracy is: 0.9627441089213998
# At random state 46, the testing accuracy is: 0.626143947297455
#
#
# At random state 47, the training accuracy is: 0.9572737663157228
# At random state 47, the testing accuracy is: 0.8116559418363323
#
#
# At random state 48, the training accuracy is: 0.9460990720082068
# At random state 48, the testing accuracy is: 0.8234694071796735
#
#
# At random state 49, the training accuracy is: 0.9871259881150014
# At random state 49, the testing accuracy is: -0.07399772649652014
#
#
# At random state 50, the training accuracy is: 0.9823137618455436
# At random state 50, the testing accuracy is: 0.6111709711670281
#
#
# At random state 51, the training accuracy is: 0.9786247301654905
# At random state 51, the testing accuracy is: 0.45827451765865546
#
#
# At random state 52, the training accuracy is: 0.9772088150616494
# At random state 52, the testing accuracy is: 0.509779369210942
#
#
# At random state 53, the training accuracy is: 0.985405526163347
# At random state 53, the testing accuracy is: 0.2550058206707254
#
#
# At random state 54, the training accuracy is: 0.9639045549917284
# At random state 54, the testing accuracy is: 0.7551746347340759
#
#
# At random state 55, the training accuracy is: 0.9548931781151017
# At random state 55, the testing accuracy is: 0.7860903369149662
#
#
# At random state 56, the training accuracy is: 0.9599022648384212
# At random state 56, the testing accuracy is: 0.6079899644109779
#
#
# At random state 57, the training accuracy is: 0.9773161013476727
# At random state 57, the testing accuracy is: -0.7979271743714555
#
#
# At random state 58, the training accuracy is: 0.9554433249805968
# At random state 58, the testing accuracy is: 0.4104992306209867
#
#
# At random state 59, the training accuracy is: 0.9860359788865672
# At random state 59, the testing accuracy is: 0.008019457575933031
#
#
# At random state 60, the training accuracy is: 0.9870382905760343
# At random state 60, the testing accuracy is: -0.41187977286947075
#
#
# At random state 61, the training accuracy is: 0.9852781686735402
# At random state 61, the testing accuracy is: -0.11594360026658412
#
#
# At random state 62, the training accuracy is: 0.9561041370877836
# At random state 62, the testing accuracy is: 0.6185871131833581
#
#
# At random state 63, the training accuracy is: 0.9579361117394376
# At random state 63, the testing accuracy is: 0.5576984549179214
#
#
# At random state 64, the training accuracy is: 0.9560367093903083
# At random state 64, the testing accuracy is: 0.6352725305739735
#
#
# At random state 65, the training accuracy is: 0.9525149014820988
# At random state 65, the testing accuracy is: 0.7247598156620808
#
#
# At random state 66, the training accuracy is: 0.9899795721247048
# At random state 66, the testing accuracy is: 0.17191346624768944
#
#
# At random state 67, the training accuracy is: 0.9489471263761321
# At random state 67, the testing accuracy is: 0.8087753828913785
#
#
# At random state 68, the training accuracy is: 0.9433712692742349
# At random state 68, the testing accuracy is: 0.873246311686587
# At random state 69, the training accuracy is: 0.9584500267196246
# At random state 69, the testing accuracy is: 0.5242852201258401
#
#
# At random state 70, the training accuracy is: 0.9669105523499831
# At random state 70, the testing accuracy is: -0.19350775611014281
#
#
# At random state 71, the training accuracy is: 0.96469155628748
# At random state 71, the testing accuracy is: 0.37909914437979975
#
#
# At random state 72, the training accuracy is: 0.9584656462802367
# At random state 72, the testing accuracy is: 0.7102012570894072
#
#
# At random state 73, the training accuracy is: 0.9669581454532016
# At random state 73, the testing accuracy is: 0.72613245446041
#
#
# At random state 74, the training accuracy is: 0.9824485230030252
# At random state 74, the testing accuracy is: -2.006452499229113
#
#
# At random state 75, the training accuracy is: 0.9619107292032067
# At random state 75, the testing accuracy is: 0.31970899130267405
#
#
# At random state 76, the training accuracy is: 0.9823020250956476
# At random state 76, the testing accuracy is: -0.5350831359882755
#
#
# At random state 77, the training accuracy is: 0.9852345925877509
# At random state 77, the testing accuracy is: -0.3919915994034082
#
#
# At random state 78, the training accuracy is: 0.9617795239455275
# At random state 78, the testing accuracy is: 0.39264201587646574
#
#
# At random state 79, the training accuracy is: 0.9746721228360482
# At random state 79, the testing accuracy is: 0.2589128063290238
#
#
# At random state 80, the training accuracy is: 0.981594071470181
# At random state 80, the testing accuracy is: -1.3881438676976656
#
#
# At random state 81, the training accuracy is: 0.9671418744471723
# At random state 81, the testing accuracy is: -3.832495192183808
#
#
# At random state 82, the training accuracy is: 0.9792528357720716
# At random state 82, the testing accuracy is: 0.7619024479455511
#
#
# At random state 83, the training accuracy is: 0.9538482413124929
# At random state 83, the testing accuracy is: 0.8479393575196416
#
#
# At random state 84, the training accuracy is: 0.9539493161516892
# At random state 84, the testing accuracy is: 0.709851296546335
#
#
# At random state 85, the training accuracy is: 0.9526629781970176
# At random state 85, the testing accuracy is: 0.8407963276845571
#
#
# At random state 86, the training accuracy is: 0.9543878085444036
# At random state 86, the testing accuracy is: 0.740493661267069
#
#
# At random state 87, the training accuracy is: 0.9631177788804777
# At random state 87, the testing accuracy is: 0.3095696288137585
#
#
# At random state 88, the training accuracy is: 0.9774273263600962
# At random state 88, the testing accuracy is: -4.229901909248953
#
#
# At random state 89, the training accuracy is: 0.9722162780072604
# At random state 89, the testing accuracy is: -0.7798144825334636
#
#
# At random state 90, the training accuracy is: 0.9530090276344044
# At random state 90, the testing accuracy is: 0.8300294405682682
#
#
# At random state 91, the training accuracy is: 0.9535273897994729
# At random state 91, the testing accuracy is: 0.6922110717277725
#
#
# At random state 92, the training accuracy is: 0.9650375090233065
# At random state 92, the testing accuracy is: 0.5943186016078801
#
#
# At random state 93, the training accuracy is: 0.9667903742911995
# At random state 93, the testing accuracy is: 0.4203580279447384
#
#
# At random state 94, the training accuracy is: 0.9714128770121186
# At random state 94, the testing accuracy is: -0.8652265962508867
#
#
# At random state 95, the training accuracy is: 0.9570916052259714
# At random state 95, the testing accuracy is: 0.5065497917815474
#
#
# At random state 96, the training accuracy is: 0.9664588096020403
# At random state 96, the testing accuracy is: 0.13466114454258227
#
#
# At random state 97, the training accuracy is: 0.949458968097837
# At random state 97, the testing accuracy is: 0.8340143915795822
#
#
# At random state 98, the training accuracy is: 0.9856174713033907
# At random state 98, the testing accuracy is: 0.569179312362768
#
#
# At random state 99, the training accuracy is: 0.9531948414942485
# At random state 99, the testing accuracy is: 0.8804448045510335
#
#
# At random state 100, the training accuracy is: 0.9596605014140273
# At random state 100, the testing accuracy is: 0.5181029019657495
#
#
# At random state 101, the training accuracy is: 0.966059509626839
# At random state 101, the testing accuracy is: 0.42707401206469575
#
#
# At random state 102, the training accuracy is: 0.9546053472717491
# At random state 102, the testing accuracy is: 0.7453702615674277
#
#
# At random state 103, the training accuracy is: 0.9478554537450424
# At random state 103, the testing accuracy is: 0.7547606178288209
#
#
# At random state 104, the training accuracy is: 0.949611911301281
# At random state 104, the testing accuracy is: 0.6874359531724169
#
#
# At random state 105, the training accuracy is: 0.9532082007454992
# At random state 105, the testing accuracy is: 0.7532946086239959
#
#
# At random state 106, the training accuracy is: 0.9704645647810072
# At random state 106, the testing accuracy is: 0.7494313780677917
#
#
# At random state 107, the training accuracy is: 0.9665200553024098
# At random state 107, the testing accuracy is: -1.3517046210865096
#
#
# At random state 108, the training accuracy is: 0.9551258022009179
# At random state 108, the testing accuracy is: 0.19714732574647142
#
#
# At random state 109, the training accuracy is: 0.9791961475563347
# At random state 109, the testing accuracy is: 0.13110913611001462
#
#
# At random state 110, the training accuracy is: 0.9827248711651714
# At random state 110, the testing accuracy is: -0.3366461892094841
#
#
# At random state 111, the training accuracy is: 0.9719838973874539
# At random state 111, the testing accuracy is: -0.7929944987123578
#
#
# At random state 112, the training accuracy is: 0.9585899900136164
# At random state 112, the testing accuracy is: 0.7000039898593121
#
#
# At random state 113, the training accuracy is: 0.9872916777457713
# At random state 113, the testing accuracy is: 0.5947652919168839
#
#
# At random state 114, the training accuracy is: 0.9470994211269033
# At random state 114, the testing accuracy is: 0.6791654851825822
#
#
# At random state 115, the training accuracy is: 0.9852084979269409
# At random state 115, the testing accuracy is: 0.5266058371623372
#
#
# At random state 116, the training accuracy is: 0.9654548244755586
# At random state 116, the testing accuracy is: 0.3939192457758126
#
#
# At random state 117, the training accuracy is: 0.9846831640743092
# At random state 117, the testing accuracy is: 0.4098532128817377
#
#
# At random state 118, the training accuracy is: 0.9543651459764084
# At random state 118, the testing accuracy is: 0.7656417016468045
#
#
# At random state 119, the training accuracy is: 0.9517302803202755
# At random state 119, the testing accuracy is: 0.8691346348539073
#
#
# At random state 120, the training accuracy is: 0.9580251553333311
# At random state 120, the testing accuracy is: 0.6671163925575092
#
#
# At random state 121, the training accuracy is: 0.9580861273602463
# At random state 121, the testing accuracy is: 0.7909666653890417
#
#
# At random state 122, the training accuracy is: 0.9773150712343709
# At random state 122, the testing accuracy is: 0.6859314992503689
#
#
# At random state 123, the training accuracy is: 0.9807223701344019
# At random state 123, the testing accuracy is: 0.46705638576436703
#
#
# At random state 124, the training accuracy is: 0.9610263399891135
# At random state 124, the testing accuracy is: 0.6736895262193643
#
#
# At random state 125, the training accuracy is: 0.9783627820087356
# At random state 125, the testing accuracy is: 0.32837316834944297
#
#
# At random state 126, the training accuracy is: 0.95635467183963
# At random state 126, the testing accuracy is: 0.4371011055083913
#
#
# At random state 127, the training accuracy is: 0.9791166505972819
# At random state 127, the testing accuracy is: 0.6185695842660944
#
#
# At random state 128, the training accuracy is: 0.9900741982697565
# At random state 128, the testing accuracy is: 0.2929071363051897
#
#
# At random state 129, the training accuracy is: 0.9599004678697278
# At random state 129, the testing accuracy is: 0.5706082388203315
#
#
# At random state 130, the training accuracy is: 0.9474895375244644
# At random state 130, the testing accuracy is: 0.7436361229323009
#
#
# At random state 131, the training accuracy is: 0.983505367399443
# At random state 131, the testing accuracy is: 0.5350478711313633
#
#
# At random state 132, the training accuracy is: 0.985788807088775
# At random state 132, the testing accuracy is: 0.2760076513543783
#
#
# At random state 133, the training accuracy is: 0.9489426820833322
# At random state 133, the testing accuracy is: 0.8705542706580991
#
#
# At random state 134, the training accuracy is: 0.9560020898228253
# At random state 134, the testing accuracy is: 0.5194256337032934
#
#
# At random state 135, the training accuracy is: 0.9478882274790026
# At random state 135, the testing accuracy is: 0.8052460196813844
#
#
# At random state 136, the training accuracy is: 0.9798719209349102
# At random state 136, the testing accuracy is: -0.09597550232755903
# At random state 137, the training accuracy is: 0.9432410313798436
# At random state 137, the testing accuracy is: 0.899817977435213
#
#
# At random state 138, the training accuracy is: 0.9667470817064818
# At random state 138, the testing accuracy is: 0.4020093721652256
#
#
# At random state 139, the training accuracy is: 0.986389056540721
# At random state 139, the testing accuracy is: -6.216142143370322
#
#
# At random state 140, the training accuracy is: 0.9633483169325199
# At random state 140, the testing accuracy is: 0.49759012001028646
#
#
# At random state 141, the training accuracy is: 0.9766019972824819
# At random state 141, the testing accuracy is: 0.5912174296673948
#
#
# At random state 142, the training accuracy is: 0.9571932467960781
# At random state 142, the testing accuracy is: 0.7331975062522871
#
#
# At random state 143, the training accuracy is: 0.981463441612748
# At random state 143, the testing accuracy is: 0.2010195594874158
#
#
# At random state 144, the training accuracy is: 0.9518242788452396
# At random state 144, the testing accuracy is: 0.765315282361571
#
#
# At random state 145, the training accuracy is: 0.9799982481836755
# At random state 145, the testing accuracy is: -1.4399650992430493
#
#
# At random state 146, the training accuracy is: 0.9816290575933383
# At random state 146, the testing accuracy is: 0.46175315076698786
#
#
# At random state 147, the training accuracy is: 0.9550892968920169
# At random state 147, the testing accuracy is: 0.5966579372031043
#
#
# At random state 148, the training accuracy is: 0.979417105997239
# At random state 148, the testing accuracy is: 0.7485019506817003
#
#
# At random state 149, the training accuracy is: 0.9515287343394175
# At random state 149, the testing accuracy is: 0.8559192903083186
#
#
# At random state 150, the training accuracy is: 0.9681956862825863
# At random state 150, the testing accuracy is: -2.3720728937092512
#
#
# At random state 151, the training accuracy is: 0.9599194845961079
# At random state 151, the testing accuracy is: 0.30192536438747464
#
#
# At random state 152, the training accuracy is: 0.9875209914162654
# At random state 152, the testing accuracy is: 0.3957685379602852
#
#
# At random state 153, the training accuracy is: 0.9869637232041536
# At random state 153, the testing accuracy is: -1.142094692229875
#
#
# At random state 154, the training accuracy is: 0.9772900807802806
# At random state 154, the testing accuracy is: -0.2900443692626271
#
#
# At random state 155, the training accuracy is: 0.9612394380774111
# At random state 155, the testing accuracy is: 0.505648377052353
#
#
# At random state 156, the training accuracy is: 0.9826613079568678
# At random state 156, the testing accuracy is: 0.2269900034160679
#
#
# At random state 157, the training accuracy is: 0.9645854107918947
# At random state 157, the testing accuracy is: 0.04666937551579231
#
#
# At random state 158, the training accuracy is: 0.9546218255038595
# At random state 158, the testing accuracy is: 0.75901387385417
#
#
# At random state 159, the training accuracy is: 0.96382293214925
# At random state 159, the testing accuracy is: 0.5192041460274908
#
#
# At random state 160, the training accuracy is: 0.9811002923273254
# At random state 160, the testing accuracy is: -0.311883447900547
#
#
# At random state 161, the training accuracy is: 0.9668504715021222
# At random state 161, the testing accuracy is: 0.5106232160187469
#
#
# At random state 162, the training accuracy is: 0.9608603924097038
# At random state 162, the testing accuracy is: 0.7122655684527084
#
#
# At random state 163, the training accuracy is: 0.9658611145813994
# At random state 163, the testing accuracy is: 0.4441159735610749
#
#
# At random state 164, the training accuracy is: 0.9598174150220984
# At random state 164, the testing accuracy is: 0.24792788227887474
#
#
# At random state 165, the training accuracy is: 0.9364264097001193
# At random state 165, the testing accuracy is: 0.9343338116280447
#
#
# At random state 166, the training accuracy is: 0.9434034656522351
# At random state 166, the testing accuracy is: -0.46240739515792884
#
#
# At random state 167, the training accuracy is: 0.9607940287726956
# At random state 167, the testing accuracy is: 0.7234136669176885
#
#
# At random state 168, the training accuracy is: 0.9772753277161512
# At random state 168, the testing accuracy is: -0.012848816658336037
#
#
# At random state 169, the training accuracy is: 0.9565877191334866
# At random state 169, the testing accuracy is: 0.4647410800444016
#
#
# At random state 170, the training accuracy is: 0.9650012836369714
# At random state 170, the testing accuracy is: 0.3100482555911316
#
#
# At random state 171, the training accuracy is: 0.957223812834641
# At random state 171, the testing accuracy is: 0.8437167304559988
#
#
# At random state 172, the training accuracy is: 0.9616187995154661
# At random state 172, the testing accuracy is: 0.20506853618318488
#
#
# At random state 173, the training accuracy is: 0.9881088533322124
# At random state 173, the testing accuracy is: -0.6509286457047296
#
#
# At random state 174, the training accuracy is: 0.9565407456038437
# At random state 174, the testing accuracy is: 0.5569355713737303
#
#
# At random state 175, the training accuracy is: 0.9732984044307865
# At random state 175, the testing accuracy is: 0.016124722563042315
#
#
# At random state 176, the training accuracy is: 0.9456478942515564
# At random state 176, the testing accuracy is: 0.9250292633017361
#
#
# At random state 177, the training accuracy is: 0.9488811565765779
# At random state 177, the testing accuracy is: 0.7624550309804514
#
#
# At random state 178, the training accuracy is: 0.9751687997083849
# At random state 178, the testing accuracy is: -0.031428142512648805
#
#
# At random state 179, the training accuracy is: 0.9682088272176871
# At random state 179, the testing accuracy is: 0.3083547005387436
#
#
# At random state 180, the training accuracy is: 0.9670584229326488
# At random state 180, the testing accuracy is: 0.5843362435795726
#
#
# At random state 181, the training accuracy is: 0.97883137344178
# At random state 181, the testing accuracy is: 0.7329093363840435
#
#
# At random state 182, the training accuracy is: 0.9560780829556178
# At random state 182, the testing accuracy is: 0.8020524706400487
#
#
# At random state 183, the training accuracy is: 0.9579757010377402
# At random state 183, the testing accuracy is: 0.6493312605271857
#
#
# At random state 184, the training accuracy is: 0.9578492136645413
# At random state 184, the testing accuracy is: 0.4158347617083775
#
#
# At random state 185, the training accuracy is: 0.9597161936567207
# At random state 185, the testing accuracy is: 0.4166865675418653
#
#
# At random state 186, the training accuracy is: 0.9598361804829229
# At random state 186, the testing accuracy is: 0.6590755387500102
#
#
# At random state 187, the training accuracy is: 0.9847465786865301
# At random state 187, the testing accuracy is: -1.1721540540111715
#
#
# At random state 188, the training accuracy is: 0.9770754792128079
# At random state 188, the testing accuracy is: 0.5488356059807232
#
#
# At random state 189, the training accuracy is: 0.954453840003697
# At random state 189, the testing accuracy is: 0.7679431232131156
#
#
# At random state 190, the training accuracy is: 0.9486763308352637
# At random state 190, the testing accuracy is: 0.8403050262755213
#
#
# At random state 191, the training accuracy is: 0.9566505389107851
# At random state 191, the testing accuracy is: 0.8018480778120534
#
#
# At random state 192, the training accuracy is: 0.9872242666657687
# At random state 192, the testing accuracy is: -3.8356324363416006
#
#
# At random state 193, the training accuracy is: 0.9410833243167975
# At random state 193, the testing accuracy is: 0.8416155493999662
#
#
# At random state 194, the training accuracy is: 0.9788908668288224
# At random state 194, the testing accuracy is: -3.7859339061594115
#
#
# At random state 195, the training accuracy is: 0.9544682151643217
# At random state 195, the testing accuracy is: 0.7703151695079434
#
#
# At random state 196, the training accuracy is: 0.9636699866048284
# At random state 196, the testing accuracy is: 0.5808124926526106
#
#
# At random state 197, the training accuracy is: 0.9616955691190746
# At random state 197, the testing accuracy is: 0.7593340070109222
#
#
# At random state 198, the training accuracy is: 0.9455979224657174
# At random state 198, the testing accuracy is: 0.8716457806151059
#
#
# At random state 199, the training accuracy is: 0.9844370368357211
# At random state 199, the testing accuracy is: -1.2407857848666555

# %% [markdown]
# At random state 176, we achieve our best accuracy of 92.5%

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=176)

# %% [markdown]
# Splitting our model into x & y with train data(x) 80% and test data(y) 20% at random state 176

# %%
lm=LinearRegression()
lm.fit(x_train,y_train)
pred=lm.predict(x_test)
print("Predicted W: ",pred)
print('actual W: ',y_test)
# Out:
# Predicted W:  [62.47000622 81.96956651 78.78508383 71.37560267 81.52230404 83.12427734]
# actual W:  19    64
# 2     81
# 9     78
# 18    68
# 12    85
# 1     83
# Name: W, dtype: int64

# %% [markdown]
# We can see there is a difference between the Predicted and the actual values. So, we will find the error rate of our model.

# %%
#Finding coefficient
lm.coef_
# Out:
# array([  7.55185321,  -1.67710285,   0.46618972,  -1.50263589,
#          0.27605347,  -2.402939  ,  -1.3678697 ,   0.78904462,
#         -0.62378099,   3.41048853,  11.25934745, -20.03226447,
#          2.16406464,   0.6781296 ,   4.77131262,  -0.02742204])

# %%
#Finding intercept
lm.intercept_
# Out:
# 80.974894687012

# %%
#training score
lm.score(x_train,y_train)
# Out:
# 0.9456478942515564

# %% [markdown]
# Our training accuracy is 94.55%

# %%
#finding errors in our Model
print('error:')
print('Mean absolute error:',mean_absolute_error(y_test,pred))
print('Mean squared error:',mean_squared_error(y_test,pred))

print('Root Mean squared error:',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# error:
# Mean absolute error: 1.710370015685817
# Mean squared error: 4.566967377202576
# Root Mean squared error: 2.13704641437723

# %% [markdown]
# We can observe quite a few errors in our model. In order to reduce the errors and increase efficiency and performance of the model, we will hypertune our model.

# %%
#Testing accuracy of the model
print(r2_score(y_test,pred))
# Out:
# 0.9250292633017361

# %% [markdown]
# Testing accuracy of the model is 92.5%. This can also be the case due to overfitting of the model. Let's do cross validation for better training and testing of data.

# %% [markdown]
# # Cross Validation of Model

# %%
#importing library for cross Validation
from sklearn.model_selection import cross_val_score

# %%
#Finding best cv score at value cv
train_accuracy=r2_score(y_train,pred_train)
test_accuracy=r2_score(y_test,pred_test)

from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(lr,x,y,cv=j)
    cv_mean=cv_score.mean()
    print(f"At cross fold {j} the cv score is {cv_mean} and accuracy score for training is {train_accuracy} and accuracy for the testing is {test_accuracy}")
    print("\n")
# Out:
# At cross fold 2 the cv score is -0.9911855504647465 and accuracy score for training is -1.305927307026876 and accuracy for the testing is -6.700301427840018
#
#
# At cross fold 3 the cv score is 0.22588460167738203 and accuracy score for training is -1.305927307026876 and accuracy for the testing is -6.700301427840018
#
#
# At cross fold 4 the cv score is 0.24952166654370012 and accuracy score for training is -1.305927307026876 and accuracy for the testing is -6.700301427840018
#
#
# At cross fold 5 the cv score is 0.04075540667455888 and accuracy score for training is -1.305927307026876 and accuracy for the testing is -6.700301427840018
#
#
# At cross fold 6 the cv score is 0.2515353093718637 and accuracy score for training is -1.305927307026876 and accuracy for the testing is -6.700301427840018
#
#
# At cross fold 7 the cv score is 0.38908046442894645 and accuracy score for training is -1.305927307026876 and accuracy for the testing is -6.700301427840018
#
#
# At cross fold 8 the cv score is 0.31937022109667906 and accuracy score for training is -1.305927307026876 and accuracy for the testing is -6.700301427840018
#
#
# At cross fold 9 the cv score is -4.809084120395514 and accuracy score for training is -1.305927307026876 and accuracy for the testing is -6.700301427840018

# %% [markdown]
# Since we get maximum accuracy at cv 7 i.e. 30.90%. So cv=7 is selected.

# %% [markdown]
# # Regularization

# %%
#Importing libraries for Regularization
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import warnings
warnings.filterwarnings('ignore')

# %%
#Finding best Parameters for Lasso Regression
from sklearn.linear_model import Lasso

parameters={'alpha':[.0001,.001,.01,.1,1,10],'random_state':list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'alpha': 1, 'random_state': 0}

# %%
#Performing Lasso Regression
ls=Lasso(alpha=1,random_state=0)
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
pred_ls=ls.predict(x_test)

lss=r2_score(y_test,pred_ls)
lss
# Out:
# 0.6771632431612664

# %% [markdown]
# The r2 score of Lasso Regression is 67.71%

# %%
cv_score=cross_val_score(ls,x,y,cv=7)
cv_mean=cv_score.mean()
cv_mean
# Out:
# 0.5682912303719384

# %% [markdown]
# The cv score is 56.82%

# %% [markdown]
# # Ensemble Technique

# %%
#Importing libraries and finding best parameters
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

parameters={'criterion':['mse','mae'],'max_features':['auto','sqrt','log2']}
rf=RandomForestRegressor()
clf=GridSearchCV(rf,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'criterion': 'mae', 'max_features': 'auto'}

# %%
#Performing RandomForestRegressor
rf=RandomForestRegressor(criterion='mse',max_features='log2')
rf.fit(x_train,y_train)
rf.score(x_train,y_train)
pred_decision=rf.predict(x_test)

rfs=r2_score(y_test,pred_decision)
print('R2 score: ',rfs*100)

rfscore=cross_val_score(rf,x,y,cv=7)
rfc=rfscore.mean()
print("Cross Val Score: ",rfc*100)
# Out:
# R2 score:  18.60465116279074
# Cross Val Score:  9.0905742783975

# %% [markdown]
# The r2 score & Cross Val Score after performing RandomForestRegressor is 18.60% & 9.06% respectively. Hence we are not able to attain maximum accuracy out of our model. The dataset seems to be asymmetric.

# %% [markdown]
# # Saving Model

# %%
import pickle
filename='baseball.pkl'
pickle.dump(rf,open(filename,'wb'))
